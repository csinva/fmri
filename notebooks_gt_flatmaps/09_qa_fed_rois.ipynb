# %%
# %load_ext autoreload
# %autoreload 2
import sys
import pandas as pd
import os
import matplotlib.pyplot as plt
import cortex
import seaborn as sns
from os.path import join
from collections import defaultdict
import numpy as np
from sklearn.preprocessing import StandardScaler
import joblib
import dvu
from copy import deepcopy
import sys
from numpy import ceil
sys.path.append('../notebooks')
from tqdm import tqdm
from sasc.config import FMRI_DIR, STORIES_DIR, RESULTS_DIR, CACHE_DIR, RESULTS_DIR, cache_ngrams_dir, regions_idxs_dir
from neuro.config import repo_dir, PROCESSED_DIR
from neuro.features.qa_questions import get_questions, get_merged_questions_v3_boostexamples
import sasc.viz
from PIL import Image
from sasc import config
# from flatmaps_helper import VOX_COUNTS, load_custom_rois, load_known_rois, ROI_EXPLANATIONS_S03, FED_DRIVING_EXPLANATIONS_S03, FED_DRIVING_EXPLANATIONS_S02
from neuro.flatmaps_helper import load_flatmaps, load_custom_rois


# main load
normalize_flatmaps = False
# gemv_flatmaps_dict_S02, gemv_flatmaps_dict_S03 = load_flatmaps(
    # normalize_flatmaps)
# gemv_flatmaps_dict_S02, gemv_flatmaps_dict_S03, gemv_flatmaps_dict_S02_timecourse, gemv_flatmaps_dict_S03_timecourse = load_flatmaps(
    # normalize_flatmaps, load_timecourse=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2
import os
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join
from tqdm import tqdm
import pandas as pd
import sys
from typing import List
import numpy as np
from copy import deepcopy
import joblib
from pprint import pprint
from math import ceil
import cortex
from neuro.config import repo_dir, PROCESSED_DIR, setup_freesurfer
from collections import defaultdict
from scipy.stats import norm
from statsmodels.stats.multitest import multipletests
import gemv
from neuro.flatmaps_helper import load_flatmaps
import sasc.viz
from neuro import analyze_helper
import nibabel as nib
neurosynth_compare = __import__('04_neurosynth_compare')
import neurosynth
from neuro.features.questions.gpt4 import QS_35_STABLE
import viz
setup_freesurfer()

subject = 'S02'
# subjects = [f'S0{i}' for i in range(1, 9) if not i == 6] # there's some problem with S06 surf2surf
subjects = ['S01', 'S02', 'S03', 'S08']

# load flatmaps
d = defaultdict(list)
for subject in subjects:
    # if subject in ['S01', 'S02', 'S03']:
    # settings = ['individual_gpt4',
    # 'individual_gpt4_wordrate', 'shapley_35']
    # else:
    settings = ['individual_gpt4_ndel=1_pc_new']
    flatmaps_qa_list = defaultdict(list)
    for setting in settings:
        flatmaps_qa_dict = joblib.load(
            join(PROCESSED_DIR, subject.replace('UT', ''), setting + '.pkl'))
        for q in flatmaps_qa_dict.keys():
            flatmaps_qa_list[q].append(flatmaps_qa_dict[q])
    flatmaps_qa_dict = {
        q: np.mean(flatmaps_qa_list[q], axis=0)
        for q in flatmaps_qa_list.keys()
    }
    # for k in sorted(flatmaps_qa_dict.keys()):
    for k in QS_35_STABLE:
        # print(k, flatmaps_qa_dict[k])
        # d[f'q_{subject}'].append(k)
        d[subject].append(flatmaps_qa_dict[k])

    # print(subject, len(flatmaps_qa_dict))
df = pd.DataFrame(d)
# df.set_index('q_S01', inplace=True)
df.index = QS_35_STABLE
df.index.name = 'question'
df = df[df.index.isin(QS_35_STABLE)]
assert df.shape[0] == 35
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def fdr_correct(pval, thres):
    """Find the fdr corrected p-value thresholds
    pval - vector of p-values
    thres - FDR level
    pID - p-value thres based on independence or positive dependence
    pN - Nonparametric p-val thres"""
    # remove NaNs
    p = pval[np.nonzero(np.isnan(pval) == False)[0]]
    p = np.sort(p)
    V = float(len(p))
    I = np.arange(V) + 1

    cVID = 1
    cVN = (1/I).sum()

    th1 = np.nonzero(p <= I/V*thres/cVID)[0]
    th2 = np.nonzero(p <= I/V*thres/cVN)[0]
    if len(th1) > 0:
        pID = p[th1.max()]
    else:
        pID = -np.inf
    if len(th2) > 0:
        pN = p[th2.max()]
    else:
        pN = -np.inf

    return pID, pN

# %%
rois_dict_fedorenko_sig = {}
subject_codes = ["UTS03", "UTS08"]
subject_code_mapping = {"UTS03": "UTS03", "UTS08": "UTS08"}

vot, vop = {}, {}
for subject_code in subject_codes:
    vot[subject_code] = np.load(
        f"{subject_code}_fedorenko_ttest_greater.npz")["vot"]
    vop[subject_code] = np.load(
        f"{subject_code}_fedorenko_ttest_greater.npz")["vop"]

for subject_code in subject_codes:
    subject = subject_code_mapping[subject_code]

    pvals = np.zeros_like(vop[subject_code]).astype(bool)
    pID, pN = fdr_correct(vop[subject_code], 0.1)
    pvals[vop[subject_code] <= pN] = 1
    rois_dict_fedorenko_sig[subject] = deepcopy(pvals)

# %%
data = joblib.load('../notebooks/results.pkl')
rr, cols_varied, mets = data['r'], data['cols_varied'], data['mets']
metric_sort = 'corrs_tune_pc_weighted_mean'
rr_best = rr[(rr.pc_components == 100) *
             (rr.ndelays == 8) *
             (rr.feature_space.str.contains('qa_emb')) *
             (rr.feature_selection_alpha < 0) *
             (rr.num_stories == -1) *
             (rr.qa_embedding_model == 'ensemble2')
             ]  # .sort_values(by='corrs_test_mean').iloc[-1]

# %% [markdown]
# ### Select avg-response flatmaps

# %%
# select
avg_defaultdict = defaultdict(list)

for subject in ['S03', 'S08']:  # , 'S02']:
    gemv_flatmaps_dict = df[subject].to_dict()

    if subject == 'S02':
        rois_dict_fedorenko_S02 = load_custom_rois(
            subject='S02', suffix_setting='_fedorenko')
        sig = np.vstack(
            list(rois_dict_fedorenko_S02.values())).sum(axis=0).astype(bool)
    else:
        sig = rois_dict_fedorenko_sig['UT' + subject]
    rois_dict = {
        subject + '_lang': sig,
        subject + '_non-lang': ~sig,
    }

    corrs_35 = rr_best[rr_best.subject == subject]['corrs_test'].iloc[0]
    sig_well_predicted = corrs_35 > 0.1
    rois_dict[subject + '_lang_ρ>0.1'] = sig_well_predicted & sig
    rois_dict[subject + '_non-lang_ρ>0.1'] = sig_well_predicted & ~sig

    ##################################################
    # compute means
    # avg_defaultdict = defaultdict(list)
    for roi_idx, roi in rois_dict.items():
        for explanation in gemv_flatmaps_dict.keys():
            avg_defaultdict[roi_idx].append(
                np.mean(gemv_flatmaps_dict[explanation][roi > 0]))
            # corrs_defaultdict[roi_idx].append(
            # np.corrcoef(roi, gemv_flatmaps_dict[explanation])[0, 1])

# %%
d = pd.DataFrame(avg_defaultdict, index=gemv_flatmaps_dict.keys())
d['AVG'] = d.mean(axis=1)

# remove 2nd val of index
d.index = [analyze_helper.abbrev_question(q) for q in d.index]

d = d.round(3).sort_values('AVG', ascending=False)
# display pandas formatting with redblue colormap centered at 0 rounded to 3 decimal places
vabs = max(abs(d.values.min()), abs(d.values.max()))
d.style.background_gradient(cmap='coolwarm', axis=None, vmax=vabs, vmin=-vabs).format("{:.3f}").set_caption(
    'Average QA coefficients for different voxel subsets'
)
# Out:
# <style type="text/css">
# #T_956be_row0_col0, #T_956be_row1_col4, #T_956be_row3_col2, #T_956be_row8_col2, #T_956be_row10_col2 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_956be_row0_col1, #T_956be_row0_col5, #T_956be_row1_col1, #T_956be_row1_col3, #T_956be_row1_col5, #T_956be_row2_col3, #T_956be_row2_col5, #T_956be_row3_col1, #T_956be_row3_col3, #T_956be_row3_col7, #T_956be_row4_col1, #T_956be_row4_col3, #T_956be_row4_col5, #T_956be_row4_col7, #T_956be_row5_col5, #T_956be_row5_col6, #T_956be_row6_col1, #T_956be_row6_col3, #T_956be_row6_col5, #T_956be_row7_col1, #T_956be_row7_col3, #T_956be_row7_col5, #T_956be_row8_col1, #T_956be_row8_col5, #T_956be_row8_col7, #T_956be_row9_col0, #T_956be_row9_col3, #T_956be_row9_col5, #T_956be_row10_col1, #T_956be_row10_col3, #T_956be_row10_col4, #T_956be_row10_col5, #T_956be_row10_col6, #T_956be_row10_col7, #T_956be_row11_col5, #T_956be_row11_col7, #T_956be_row12_col5, #T_956be_row12_col7, #T_956be_row13_col0, #T_956be_row13_col1, #T_956be_row13_col3, #T_956be_row13_col4, #T_956be_row13_col5, #T_956be_row13_col7, #T_956be_row13_col8, #T_956be_row14_col0, #T_956be_row14_col1, #T_956be_row14_col3, #T_956be_row14_col8, #T_956be_row15_col0, #T_956be_row15_col5, #T_956be_row15_col8, #T_956be_row16_col1, #T_956be_row16_col3, #T_956be_row16_col5, #T_956be_row16_col7, #T_956be_row16_col8, #T_956be_row17_col4, #T_956be_row17_col5, #T_956be_row17_col8, #T_956be_row18_col2, #T_956be_row18_col5, #T_956be_row18_col8, #T_956be_row19_col1, #T_956be_row19_col5, #T_956be_row19_col7, #T_956be_row19_col8, #T_956be_row20_col1, #T_956be_row20_col4, #T_956be_row20_col5, #T_956be_row20_col7, #T_956be_row20_col8, #T_956be_row21_col1, #T_956be_row21_col3, #T_956be_row22_col0, #T_956be_row22_col2, #T_956be_row22_col4, #T_956be_row22_col5, #T_956be_row23_col3, #T_956be_row23_col4, #T_956be_row23_col5, #T_956be_row23_col7, #T_956be_row24_col1, #T_956be_row24_col5, #T_956be_row25_col1, #T_956be_row25_col3, #T_956be_row26_col1, #T_956be_row27_col2, #T_956be_row28_col1, #T_956be_row28_col5, #T_956be_row29_col5, #T_956be_row30_col1, #T_956be_row31_col5, #T_956be_row32_col3, #T_956be_row33_col1, #T_956be_row34_col1, #T_956be_row34_col5 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_956be_row0_col2 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_956be_row0_col3, #T_956be_row2_col1, #T_956be_row5_col4, #T_956be_row8_col3, #T_956be_row8_col4, #T_956be_row9_col1, #T_956be_row9_col7, #T_956be_row13_col2, #T_956be_row14_col4, #T_956be_row14_col5, #T_956be_row15_col1, #T_956be_row15_col2, #T_956be_row15_col3, #T_956be_row16_col0, #T_956be_row18_col7, #T_956be_row19_col3, #T_956be_row20_col3, #T_956be_row20_col6, #T_956be_row21_col7, #T_956be_row21_col8, #T_956be_row22_col1, #T_956be_row22_col3, #T_956be_row22_col6, #T_956be_row22_col7, #T_956be_row22_col8, #T_956be_row23_col6, #T_956be_row23_col8, #T_956be_row24_col2, #T_956be_row24_col3, #T_956be_row24_col8, #T_956be_row25_col8, #T_956be_row26_col3, #T_956be_row26_col4, #T_956be_row26_col5, #T_956be_row26_col7, #T_956be_row26_col8, #T_956be_row27_col5, #T_956be_row27_col8, #T_956be_row28_col3, #T_956be_row28_col7, #T_956be_row33_col3, #T_956be_row34_col3 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_956be_row0_col4, #T_956be_row1_col2, #T_956be_row9_col6, #T_956be_row16_col6, #T_956be_row25_col2, #T_956be_row27_col3 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_956be_row0_col6, #T_956be_row3_col0, #T_956be_row4_col0, #T_956be_row4_col2, #T_956be_row8_col0, #T_956be_row10_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_956be_row0_col7, #T_956be_row1_col7, #T_956be_row2_col0, #T_956be_row2_col7, #T_956be_row3_col4, #T_956be_row3_col8, #T_956be_row5_col0, #T_956be_row5_col2, #T_956be_row5_col3, #T_956be_row6_col0, #T_956be_row6_col2, #T_956be_row7_col0, #T_956be_row9_col4, #T_956be_row11_col4, #T_956be_row12_col0, #T_956be_row12_col2, #T_956be_row12_col3, #T_956be_row12_col6, #T_956be_row15_col4, #T_956be_row17_col3, #T_956be_row18_col1, #T_956be_row21_col0, #T_956be_row29_col1, #T_956be_row29_col3 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_956be_row0_col8, #T_956be_row1_col0, #T_956be_row1_col8, #T_956be_row2_col2, #T_956be_row2_col8, #T_956be_row3_col6, #T_956be_row7_col2, #T_956be_row11_col6, #T_956be_row15_col6, #T_956be_row16_col4, #T_956be_row18_col3, #T_956be_row19_col0, #T_956be_row19_col2, #T_956be_row20_col0, #T_956be_row20_col2, #T_956be_row21_col2, #T_956be_row25_col0, #T_956be_row27_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_956be_row1_col6 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_956be_row2_col4 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_956be_row2_col6 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_956be_row3_col5, #T_956be_row4_col4, #T_956be_row4_col6, #T_956be_row4_col8, #T_956be_row5_col1, #T_956be_row5_col8, #T_956be_row6_col4, #T_956be_row6_col6, #T_956be_row6_col7, #T_956be_row6_col8, #T_956be_row7_col4, #T_956be_row7_col6, #T_956be_row7_col7, #T_956be_row7_col8, #T_956be_row8_col8, #T_956be_row9_col2, #T_956be_row9_col8, #T_956be_row10_col8, #T_956be_row11_col0, #T_956be_row11_col1, #T_956be_row11_col2, #T_956be_row11_col3, #T_956be_row11_col8, #T_956be_row12_col1, #T_956be_row12_col4, #T_956be_row12_col8, #T_956be_row14_col2, #T_956be_row14_col7, #T_956be_row15_col7, #T_956be_row17_col1, #T_956be_row17_col6, #T_956be_row17_col7, #T_956be_row18_col0, #T_956be_row21_col5, #T_956be_row23_col1, #T_956be_row24_col0, #T_956be_row27_col0, #T_956be_row30_col3, #T_956be_row31_col1, #T_956be_row31_col3, #T_956be_row32_col0, #T_956be_row32_col1, #T_956be_row32_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_956be_row5_col7, #T_956be_row8_col6, #T_956be_row13_col6, #T_956be_row16_col2, #T_956be_row17_col0, #T_956be_row17_col2, #T_956be_row18_col4, #T_956be_row19_col4, #T_956be_row23_col0, #T_956be_row24_col7, #T_956be_row25_col4, #T_956be_row25_col5, #T_956be_row26_col0, #T_956be_row26_col2, #T_956be_row26_col6, #T_956be_row28_col0, #T_956be_row28_col4, #T_956be_row28_col8, #T_956be_row29_col7, #T_956be_row29_col8, #T_956be_row30_col5, #T_956be_row32_col5, #T_956be_row33_col0, #T_956be_row33_col2 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_956be_row14_col6, #T_956be_row18_col6, #T_956be_row19_col6, #T_956be_row21_col4, #T_956be_row23_col2, #T_956be_row24_col4, #T_956be_row25_col7, #T_956be_row27_col4, #T_956be_row27_col7, #T_956be_row28_col2, #T_956be_row29_col0, #T_956be_row30_col0, #T_956be_row30_col2, #T_956be_row30_col8, #T_956be_row31_col7 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_956be_row21_col6, #T_956be_row31_col4, #T_956be_row32_col7, #T_956be_row34_col0 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_956be_row24_col6, #T_956be_row27_col6, #T_956be_row30_col4, #T_956be_row31_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_956be_row25_col6, #T_956be_row28_col6, #T_956be_row29_col2, #T_956be_row30_col7, #T_956be_row31_col8, #T_956be_row33_col5 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_956be_row29_col4, #T_956be_row31_col0, #T_956be_row32_col8 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_956be_row29_col6, #T_956be_row33_col8, #T_956be_row34_col7 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_956be_row30_col6, #T_956be_row34_col2, #T_956be_row34_col8 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_956be_row31_col6 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_956be_row32_col4, #T_956be_row33_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_956be_row32_col6 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_956be_row33_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_956be_row33_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_956be_row34_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_956be_row34_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_956be">
#   <caption>Average QA coefficients for different voxel subsets</caption

# %%
plt.figure(figsize=(15, 10))
# add label to cbar
sns.heatmap(df, annot=True, fmt='.3f', cmap='coolwarm', center=0, vmin=-vabs, vmax=vabs,
            annot_kws={"size": 10}, cbar_kws={"label": "Average GEM-V driving response"}, linewidths=.5)
plt.tight_layout()
plt.savefig('fed_drive_full.pdf')

# %%
for subject in ['S03', 'S02']:
    if subject == 'S03':
        FED_DRIVING_EXPLANATIONS = FED_DRIVING_EXPLANATIONS_S03
    elif subject == 'S02':
        FED_DRIVING_EXPLANATIONS = FED_DRIVING_EXPLANATIONS_S02
    cols = [f'Lang-{i} {subject}' for i in range(4)]
    df_3 = df.loc[FED_DRIVING_EXPLANATIONS.values()][cols].rename(columns={
        k: k.replace(f' {subject}', '') for k in cols
    })
    plt.figure(figsize=(10, 6))
    # make fontsizes small
    sns.heatmap(df_3, annot=True, fmt='.3f', cmap='coolwarm', center=0, vmin=-vabs, vmax=vabs,
                cbar_kws={"label": "Average GEM-V driving response"}, linewidths=.5)
    dvu.outline_diagonal(df_3.values.shape, roffset=0.5,
                         coffset=0.5, color='black', lw=2)
    plt.tight_layout()
    plt.savefig(f'fed_drive_{subject}.pdf', bbox_inches='tight')

# %%
# sasc.viz._save_flatmap(
#     gemv_flatmaps_dict[('relationships between people', 'qa')], subject, fname_save=f'gemv_flatmaps/relationships_{subject}.png')

# %% [markdown]
# # Show flatmaps across subjects

# %%
S02_flatmaps_dir = join(RESULTS_DIR, 'processed',
                        'flatmaps_all', 'UTS02', 'roi')
S03_flatmaps_dir = join(RESULTS_DIR, 'processed',
                        'flatmaps_all', 'UTS03', 'roi')

# %%
# read a list of pngs and save them as a grid
for COMPARISONS in [
    ['Years', 'Time', 'Numbers', 'Measurements'],
    ['Relationships', 'Dialogue', 'Introspection'],
    ['Gruesome', 'Fear', 'Positive Emotional', 'Negative Emotional'],
    ['Clothing', 'Color'],
    ['Sexual', 'Secretive', 'Recognition', 'Professions']
]:

    pngs = defaultdict(list)
    for s in COMPARISONS:
        pngs['S02'] += [join(S02_flatmaps_dir, f)
                        for f in os.listdir(S02_flatmaps_dir) if f.endswith('.png') and s in f]
        pngs['S03'] += [join(S03_flatmaps_dir, f)
                        for f in os.listdir(S03_flatmaps_dir) if f.endswith('.png') and s in f]

    # plot as grid
    fig, axes = plt.subplots(
        2, len(COMPARISONS), figsize=(len(COMPARISONS) * 5, 6))
    for i, ax in enumerate(axes.flatten()):
        # ax.axis('off')
        # Remove all x-axis ticks and labels
        ax.xaxis.set_ticks([])
        ax.xaxis.set_ticklabels([])
        ax.xaxis.label.set_visible(False)

        # Remove all y-axis ticks and labels (but keep the y-axis label)
        ax.yaxis.set_ticks([])
        ax.yaxis.set_ticklabels([])

        for spine in ax.spines.values():
            spine.set_visible(False)

    for i in range(len(COMPARISONS)):
        axes[0, i].imshow(plt.imread(pngs['S02'][i]))
        axes[0, i].set_title(COMPARISONS[i])
        axes[1, i].imshow(plt.imread(pngs['S03'][i]))
        axes[0, 0].set_ylabel('S02')
        axes[1, 0].set_ylabel('S03')

    # add
    plt.savefig('__'.join(COMPARISONS) + '.png', bbox_inches='tight', dpi=300)
    plt.show()
