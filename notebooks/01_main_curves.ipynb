# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')
sys.path.append('../experiments')
import dvu
import seaborn as sns
import os
import pandas as pd
from copy import deepcopy
from matplotlib import pyplot as plt
from os.path import join
import numpy as np
import imodelsx.process_results
import neuro.features.qa_questions as qa_questions
import joblib
from tqdm import tqdm
import analyze_helper
import viz
fit_encoding = __import__('02_fit_encoding')
dvu.set_style()

results_dir = analyze_helper.best_results_dir
rr, cols_varied, mets = analyze_helper.load_clean_results(results_dir)
# r = r[r.feature_selection_alpha_index < 0]
# r = r[r.pc_components == 100]

metric_sort = 'corrs_tune_pc_weighted_mean'
# r = analyze_helper.add_corrs_tune_pc_weighted(r)
# metric_sort = 'corrs_tune_pc_weighted_mean'
# mets.append(metric_sort)
# Out:
#   1%|          | 10/1294 [00:01<02:28,  8.64it/s]
# Error loading /home/chansingh/mntv1/deep-fMRI/encoding/may7/025c5adb13d2819b85082e53501a627e5b5bf8450601aea32ca46b953f120012/results.pkl
#  72%|███████▏  | 932/1294 [02:29<00:54,  6.65it/s]
# Error loading /home/chansingh/mntv1/deep-fMRI/encoding/may7/b83439914e4d5e0df857e5a68726be3ddc1d57c6c86c7a496a491986c7cb1751/results.pkl
# 100%|██████████| 1294/1294 [03:27<00:00,  6.22it/s]
# experiment varied these params: ['subject', 'num_stories', 'feature_space', 'embedding_layer', 'feature_selection_alpha', 'feature_selection_stability_seeds', 'qa_embedding_model', 'qa_questions_version', 'ndelays']

# %%
r = rr[rr.qa_questions_version.isin(
    ['',
     'v3_boostexamples',
     'v3_boostexamples_merged'
     ])]
r = r[r.num_stories == -1]
r = r[r.feature_selection_alpha == -1]
r = r[~r.feature_space.isin(
    ['meta-llama/Llama-2-7b-hf', 'meta-llama/Meta-Llama-3-8B'])]
cols_varied = [c for c in cols_varied if not c in ['num_stories',
                                                   'feature_selection_alpha', 'feature_selection_stability_seeds']]
r.shape
# Out:
# (303, 59)

# %% [markdown]
# ### best results breakdown

# %%
d = r
# d = d[~((d.feature_space == 'qa_embedder-10') & (d.ndelays != 8))]
d = d[~((d.feature_space == 'qa_embedder') &
        (d.qa_embedding_model != 'ensemble1'))]
d = d[~((d.feature_space == 'qa_embedder') &
        (d.ndelays != 8))]
d = d[~((d.feature_space.str.contains('llama')) & (d.ndelays != 4))]
# d = d[~((d.feature_space.str.contains('bert')) & (d.ndelays != 4))]
d = d[d.pc_components == 100]

d = d.sort_values(
    by=metric_sort, ascending=False)
d = d.groupby(['subject', 'feature_space_simplified'])[mets]
d = d.first().reset_index()
# display(d)
tab = d.pivot_table(index='subject', columns='feature_space_simplified',
                    values='corrs_test_mean', aggfunc='mean')
# d.pivot_table(index='subject', columns='feature_space_simplified',
#                     values='corrs_test_mean_sem', aggfunc='mean')

# add average row
tab.loc['AVG'] = tab.mean()
# display(tab.round(3))

tab['Subject'] = tab.index.str.replace('UT', '')
# rename stuf
tab.columns = tab.columns.map(viz.feature_space_rename)
display(tab)

plot_data = tab.melt(id_vars='Subject',
                     var_name='feature_space_simplified', value_name='corrs_test_mean')
# fig, ax = plt.subplots(figsize=(4, 3))
plt.figure(figsize=(4.5, 3.2))
sns.barplot(
    plot_data, x='Subject', y='corrs_test_mean',
    hue='feature_space_simplified',
    hue_order=[
        'Eng1000', 'QA-Emb', 'BERT', 'LLaMA'],
    palette=['tomato', 'C0', '#777', '#333'])  # blues: '#52aae7', 'C0', '#004481'
# move legend outside
plt.legend(frameon=False)  # , bbox_to_anchor=(0.75, 1.2))
plt.ylabel('Test correlation')
# plt.ylim((0.05, 0.15))
plt.tight_layout()
plt.savefig('../figs/corr_best.pdf', bbox_inches='tight')
plt.show()
# Out:
# feature_space_simplified      BERT   Eng1000     LLaMA    QA-Emb Subject
# subject
# S01                       0.056404  0.049082  0.040163  0.057637     S01
# S02                       0.112266  0.095025  0.129774  0.120674     S02
# S03                       0.133466  0.106534  0.141692  0.133804     S03
# S04                       0.000570  0.038322  0.025816  0.017847     S04
# S05                       0.010097  0.016812  0.006638  0.007969     S05
# S06                       0.035421  0.018711  0.040702  0.032639     S06
# S07                       0.021566  0.018535  0.024591  0.021452     S07
# S08                       0.008002  0.015689  0.006872  0.007581     S08
# AVG                       0.047224  0.044839  0.052031  0.049950     AVG

# %%
# t = tab.round(3)[['QA-Emb', 'QA-Emb (distill)',
#                   'QA-Emb (distill logits)', 'Eng1000']].astype(str)
# # bold the bottom row
# t.loc['AVG'] = t.loc['AVG'].apply(lambda x: f'\\textbf{{{x}}}')
# # bold AVG index label
# t = t.rename(index={'AVG': '\\textbf{AVG}'})
# # delete the column label name
# t.columns.name = None
# t.index.name = None

# # export to latex using booktabs
# print(t.to_latex(escape=False, column_format='lrrrr', float_format='%.3f'))

# %% [markdown]
# ### qa version breakdowns

# %%
d = r[(r.feature_space == 'qa_embedder')]
d = d[(d.pc_components == 100)]
# d = d[d.ndelays == 8]
# d = d[~d.qa_embedding_model.str.contains('mixt')]
d['qa_questions_version'] = d['qa_questions_version'].apply(
    viz.version_rename)
cols = ['subject', 'ndelays', 'qa_questions_version', 'qa_embedding_model']
d = d.groupby(cols)[mets].mean()
d = (
    d.pivot_table(index=[c for c in cols if not c == 'qa_embedding_model'],
                  columns='qa_embedding_model', values='corrs_test_mean', aggfunc='mean')
)
# add average row to multiindex
# for qa_questions_version in sorted(d.index.get_level_values('qa_questions_version').unique()):
# dn = d.loc[(slice(None), qa_questions_version), :]
# d.loc[('AVG', qa_questions_version), :] = dn.mean()
display(
    d
    .style.background_gradient(cmap='magma')  # , axis=1)  # , axis=0)
    .format(precision=3)
)

# d = d.drop(columns='llama3-8B-refined')
# d.columns.name = None
# d.index.names = ['Subject', 'Questions']
# d.columns = d.columns.map(viz.feature_space_rename)
# d = d.loc[(slice(None), ['Prompts 1-3 (376 questions)',
#            'Prompts 1-5 (518 questions)', 'Prompts 1-6 (674 questions)']), :]
# print(d.to_latex(escape=False, float_format='%.3f').replace(
#     '\cline{1-5}', '\midrule'))
# Out:
# <style type="text/css">
# #T_5c9a4_row0_col0 {
#   background-color: #812581;
#   color: #f1f1f1;
# }
# #T_5c9a4_row0_col1, #T_5c9a4_row3_col0 {
#   background-color: #912b81;
#   color: #f1f1f1;
# }
# #T_5c9a4_row0_col2, #T_5c9a4_row1_col0 {
#   background-color: #842681;
#   color: #f1f1f1;
# }
# #T_5c9a4_row0_col3, #T_5c9a4_row1_col2, #T_5c9a4_row1_col4, #T_5c9a4_row2_col3, #T_5c9a4_row3_col2, #T_5c9a4_row3_col4, #T_5c9a4_row4_col3, #T_5c9a4_row5_col2, #T_5c9a4_row5_col4, #T_5c9a4_row6_col3, #T_5c9a4_row7_col2, #T_5c9a4_row7_col4, #T_5c9a4_row8_col3, #T_5c9a4_row9_col2, #T_5c9a4_row9_col4, #T_5c9a4_row10_col3, #T_5c9a4_row11_col2, #T_5c9a4_row11_col4, #T_5c9a4_row12_col3, #T_5c9a4_row13_col2, #T_5c9a4_row13_col4, #T_5c9a4_row14_col3, #T_5c9a4_row15_col2, #T_5c9a4_row15_col4, #T_5c9a4_row17_col2, #T_5c9a4_row17_col4, #T_5c9a4_row18_col3, #T_5c9a4_row19_col2, #T_5c9a4_row19_col4, #T_5c9a4_row20_col3, #T_5c9a4_row21_col2, #T_5c9a4_row21_col4, #T_5c9a4_row22_col3, #T_5c9a4_row23_col2, #T_5c9a4_row23_col4, #T_5c9a4_row24_col3, #T_5c9a4_row25_col2, #T_5c9a4_row25_col4, #T_5c9a4_row26_col3, #T_5c9a4_row27_col2, #T_5c9a4_row27_col4, #T_5c9a4_row28_col3, #T_5c9a4_row29_col2, #T_5c9a4_row29_col4, #T_5c9a4_row30_col3, #T_5c9a4_row31_col2, #T_5c9a4_row31_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_5c9a4_row0_col4 {
#   background-color: #882781;
#   color: #f1f1f1;
# }
# #T_5c9a4_row1_col1 {
#   background-color: #902a81;
#   color: #f1f1f1;
# }
# #T_5c9a4_row1_col3 {
#   background-color: #982d80;
#   color: #f1f1f1;
# }
# #T_5c9a4_row2_col0, #T_5c9a4_row2_col2 {
#   background-color: #862781;
#   color: #f1f1f1;
# }
# #T_5c9a4_row2_col1 {
#   background-color: #9c2e7f;
#   color: #f1f1f1;
# }
# #T_5c9a4_row2_col4 {
#   background-color: #8e2a81;
#   color: #f1f1f1;
# }
# #T_5c9a4_row3_col1 {
#   background-color: #a02f7f;
#   color: #f1f1f1;
# }
# #T_5c9a4_row3_col3 {
#   background-color: #aa337d;
#   color: #f1f1f1;
# }
# #T_5c9a4_row4_col0, #T_5c9a4_row4_col4, #T_5c9a4_row5_col1 {
#   background-color: #fed194;
#   color: #000000;
# }
# #T_5c9a4_row4_col1 {
#   background-color: #fed89a;
#   color: #000000;
# }
# #T_5c9a4_row4_col2 {
#   background-color: #febf84;
#   color: #000000;
# }
# #T_5c9a4_row5_col0, #T_5c9a4_row6_col0 {
#   background-color: #fecf92;
#   color: #000000;
# }
# #T_5c9a4_row5_col3, #T_5c9a4_row7_col3 {
#   background-color: #fcf4b6;
#   color: #000000;
# }
# #T_5c9a4_row6_col1 {
#   background-color: #fed799;
#   color: #000000;
# }
# #T_5c9a4_row6_col2 {
#   background-color: #feca8d;
#   color: #000000;
# }
# #T_5c9a4_row6_col4 {
#   background-color: #fec488;
#   color: #000000;
# }
# #T_5c9a4_row7_col0 {
#   background-color: #fecc8f;
#   color: #000000;
# }
# #T_5c9a4_row7_col1, #T_5c9a4_row8_col4 {
#   background-color: #fdda9c;
#   color: #000000;
# }
# #T_5c9a4_row8_col0, #T_5c9a4_row8_col1, #T_5c9a4_row9_col1 {
#   background-color: #fcf0b2;
#   color: #000000;
# }
# #T_5c9a4_row8_col2 {
#   background-color: #fde3a5;
#   color: #000000;
# }
# #T_5c9a4_row9_col0 {
#   background-color: #fde9aa;
#   color: #000000;
# }
# #T_5c9a4_row9_col3, #T_5c9a4_row10_col1, #T_5c9a4_row10_col2, #T_5c9a4_row10_col4, #T_5c9a4_row11_col0 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_5c9a4_row10_col0 {
#   background-color: #fcf9bb;
#   color: #000000;
# }
# #T_5c9a4_row11_col1 {
#   background-color: #fcfbbd;
#   color: #000000;
# }
# #T_5c9a4_row11_col3 {
#   background-color: #fcf7b9;
#   color: #000000;
# }
# #T_5c9a4_row12_col0, #T_5c9a4_row15_col3, #T_5c9a4_row18_col1, #T_5c9a4_row28_col2, #T_5c9a4_row28_col4 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_5c9a4_row12_col1 {
#   background-color: #400f74;
#   color: #f1f1f1;
# }
# #T_5c9a4_row12_col2, #T_5c9a4_row14_col0, #T_5c9a4_row27_col0 {
#   background-color: #160f3b;
#   color: #f1f1f1;
# }
# #T_5c9a4_row12_col4, #T_5c9a4_row20_col1 {
#   background-color: #451077;
#   color: #f1f1f1;
# }
# #T_5c9a4_row13_col0, #T_5c9a4_row24_col0, #T_5c9a4_row26_col0 {
#   background-color: #21114e;
#   color: #f1f1f1;
# }
# #T_5c9a4_row13_col1 {
#   background-color: #3d0f71;
#   color: #f1f1f1;
# }
# #T_5c9a4_row13_col3, #T_5c9a4_row28_col0 {
#   background-color: #0a0822;
#   color: #f1f1f1;
# }
# #T_5c9a4_row14_col1 {
#   background-color: #110c2f;
#   color: #f1f1f1;
# }
# #T_5c9a4_row14_col2, #T_5c9a4_row15_col0 {
#   background-color: #0d0a29;
#   color: #f1f1f1;
# }
# #T_5c9a4_row14_col4, #T_5c9a4_row18_col2 {
#   background-color: #120d31;
#   color: #f1f1f1;
# }
# #T_5c9a4_row15_col1 {
#   background-color: #1c1044;
#   color: #f1f1f1;
# }
# #T_5c9a4_row16_col0, #T_5c9a4_row16_col2, #T_5c9a4_row17_col0 {
#   background-color: #100b2d;
#   color: #f1f1f1;
# }
# #T_5c9a4_row16_col1, #T_5c9a4_row16_col3, #T_5c9a4_row16_col4 {
#   background-color: #130d34;
#   color: #f1f1f1;
# }
# #T_5c9a4_row17_col1 {
#   background-color: #0b0924;
#   color: #f1f1f1;
# }
# #T_5c9a4_row17_col3, #T_5c9a4_row18_col4, #T_5c9a4_row29_col3 {
#   background-color: #0e0b2b;
#   color: #f1f1f1;
# }
# #T_5c9a4_row18_col0 {
#   background-color: #030312;
#   color: #f1f1f1;
# }
# #T_5c9a4_row19_col0 {
#   background-color: #20114b;
#   color: #f1f1f1;
# }
# #T_5c9a4_row19_col1 {
#   background-color: #19103f;
#   color: #f1f1f1;
# }
# #T_5c9a4_row19_col3 {
#   background-color: #010108;
#   color: #f1f1f1;
# }
# #T_5c9a4_row20_col0, #T_5c9a4_row21_col0 {
#   background-color: #59157e;
#   color: #f1f1f1;
# }
# #T_5c9a4_row20_col2, #T_5c9a4_row21_col1 {
#   background-color: #471078;
#   color: #f1f1f1;
# }
# #T_5c9a4_row20_col4 {
#   background-color: #4e117b;
#   color: #f1f1f1;
# }
# #T_5c9a4_row21_col3, #T_5c9a4_row25_col0 {
#   background-color: #390f6e;
#   color: #f1f1f1;
# }
# #T_5c9a4_row22_col0 {
#   background-color: #440f76;
#   color: #f1f1f1;
# }
# #T_5c9a4_row22_col1, #T_5c9a4_row24_col2, #T_5c9a4_row25_col3 {
#   background-color: #251255;
#   color: #f1f1f1;
# }
# #T_5c9a4_row22_col2 {
#   background-color: #341069;
#   color: #f1f1f1;
# }
# #T_5c9a4_row22_col4, #T_5c9a4_row24_col4 {
#   background-color: #2a115c;
#   color: #f1f1f1;
# }
# #T_5c9a4_row23_col0 {
#   background-color: #331067;
#   color: #f1f1f1;
# }
# #T_5c9a4_row23_col1 {
#   background-color: #311165;
#   color: #f1f1f1;
# }
# #T_5c9a4_row23_col3, #T_5c9a4_row26_col2, #T_5c9a4_row27_col1 {
#   background-color: #180f3d;
#   color: #f1f1f1;
# }
# #T_5c9a4_row24_col1 {
#   background-color: #2f1163;
#   color: #f1f1f1;
# }
# #T_5c9a4_row25_col1 {
#   background-color: #2d1161;
#   color: #f1f1f1;
# }
# #T_5c9a4_row26_col1, #T_5c9a4_row26_col4 {
#   background-color: #1a1042;
#   color: #f1f1f1;
# }
# #T_5c9a4_row27_col3 {
#   background-color: #0c0926;
#   color: #f1f1f1;
# }
# #T_5c9a4_row28_col1 {
#   background-color: #08071e;
#   color: #f1f1f1;
# }
# #T_5c9a4_row29_col0, #T_5c9a4_row29_col1 {
#   background-color: #090720;
#   color: #f1f1f1;
# }
# #T_5c9a4_row30_col0 {
#   background-color: #02020d;
#   color: #f1f1f1;
# }
# #T_5c9a4_row30_col1 {
#   background-color: #040414;
#   color: #f1f1f1;
# }
# #T_5c9a4_row30_col2 {
#   background-color: #020109;
#   color: #f1f1f1;
# }
# #T_5c9a4_row30_col4 {
#   background-color: #050416;
#   color: #f1f1f1;
# }
# #T_5c9a4_row31_col0, #T_5c9a4_row31_col3 {
#   background-color: #03030f;
#   color: #f1f1f1;
# }
# #T_5c9a4_row31_col1 {
#   background-color: #02020b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5c9a4">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >qa_embedding_model</th>
#       <th id="T_5c9a4_level0_col0" class="col_heading level0 col0" >ensemble1</th>
#       <th id="T_5c9a4_level0_col1" class="col_heading level0 col1" >llama3-8B</th>
#       <th id="T_5c9a4_level0_col2" class="col_heading level0 col2" >llama3-8B-fewshot</th>
#       <th id="T_5c9a4_level0_col3" class="col_heading level0 col3" >meta-llama/Meta-Llama-3-70B-Instruct</th>
#       <th id="T_5c9a4_level0_col4" class="col_heading level0 col4" >mist-7B</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >subject</th>
#       <th class="index_name level1" >ndelays</th>
#       <th class="index_name level2" >qa_questions_version</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c9a4_level0_row0" class="row_headin

# %%
d = r[(~r.feature_space.str.contains('qa_embedder'))]
d = d[d.pc_components == 100]
d = d[(~d.feature_space.str.contains('roberta'))]
# d = r[(r.pc_components == 100)]
# d = d[d.ndelays == 8]
cols = [c for c in cols_varied if not c in [
    'qa_embedding_model', 'qa_questions_version']]
if not 'subject' in cols:
    cols_varied.append('subject')
cols_top = ['feature_space', 'embedding_layer']
d = d.groupby(cols_varied)[mets].mean()
d = (
    d.pivot_table(index=[c for c in cols if not c in cols_top],
                  columns=cols_top, values='corrs_test_mean', aggfunc='mean')
    .rename(columns=viz.feature_space_rename)
    # sort columns alphabetically
    .sort_index(axis=1)
)
# add average row to multiindex
# for ndelays in sorted(d.index.get_level_values('ndelays').unique()):
#     dn = d.loc[(slice(None), ndelays), :]
#     d.loc[('AVG', ndelays), :] = dn.mean()


# d.columns.name = None
# d.index.names = ['Subject', 'Delays']
display(d
        .style.background_gradient(cmap='viridis', axis=1)  # , axis=0)
        .format(precision=3)
        )
# print(d.T.to_latex(escape=False, float_format='%.3f'))
# Out:
# <style type="text/css">
# #T_ad12f_row0_col0, #T_ad12f_row3_col5 {
#   background-color: #1f988b;
#   color: #f1f1f1;
# }
# #T_ad12f_row0_col1 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_ad12f_row0_col2 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_ad12f_row0_col3, #T_ad12f_row1_col11, #T_ad12f_row2_col1, #T_ad12f_row3_col7, #T_ad12f_row4_col1, #T_ad12f_row5_col1, #T_ad12f_row6_col0, #T_ad12f_row7_col0, #T_ad12f_row8_col2, #T_ad12f_row9_col0, #T_ad12f_row10_col1, #T_ad12f_row11_col1, #T_ad12f_row12_col7, #T_ad12f_row13_col3, #T_ad12f_row14_col4, #T_ad12f_row15_col5 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_ad12f_row0_col4 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_ad12f_row0_col5 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_ad12f_row0_col6 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_ad12f_row0_col7 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_ad12f_row0_col8, #T_ad12f_row1_col4, #T_ad12f_row2_col4, #T_ad12f_row3_col0, #T_ad12f_row4_col3, #T_ad12f_row5_col4, #T_ad12f_row6_col1, #T_ad12f_row7_col9, #T_ad12f_row8_col4, #T_ad12f_row9_col1, #T_ad12f_row10_col9, #T_ad12f_row11_col3, #T_ad12f_row12_col3, #T_ad12f_row13_col9, #T_ad12f_row14_col1, #T_ad12f_row15_col11 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_ad12f_row0_col9, #T_ad12f_row7_col4, #T_ad12f_row11_col11, #T_ad12f_row12_col4 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_ad12f_row0_col10, #T_ad12f_row15_col4 {
#   background-color: #443b84;
#   color: #f1f1f1;
# }
# #T_ad12f_row0_col11, #T_ad12f_row8_col7 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_ad12f_row1_col0 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_ad12f_row1_col1, #T_ad12f_row2_col10, #T_ad12f_row9_col10 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_ad12f_row1_col2, #T_ad12f_row12_col1 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_ad12f_row1_col3 {
#   background-color: #2a768e;
#   color: #f1f1f1;
# }
# #T_ad12f_row1_col5, #T_ad12f_row3_col6 {
#   background-color: #2e6d8e;
#   color: #f1f1f1;
# }
# #T_ad12f_row1_col6 {
#   background-color: #38598c;
#   color: #f1f1f1;
# }
# #T_ad12f_row1_col7 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_ad12f_row1_col8 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_ad12f_row1_col9 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_ad12f_row1_col10, #T_ad12f_row5_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ad12f_row2_col0 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_ad12f_row2_col2 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_ad12f_row2_col3 {
#   background-color: #dae319;
#   color: #000000;
# }
# #T_ad12f_row2_col5, #T_ad12f_row5_col2 {
#   background-color: #7fd34e;
#   color: #000000;
# }
# #T_ad12f_row2_col6, #T_ad12f_row7_col2, #T_ad12f_row9_col6 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_ad12f_row2_col7 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_ad12f_row2_col8, #T_ad12f_row14_col9 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_ad12f_row2_col9, #T_ad12f_row4_col11, #T_ad12f_row11_col9 {
#   background-color: #9bd93c;
#   color: #000000;
# }
# #T_ad12f_row2_col11 {
#   background-color: #3bbb75;
#   color: #f1f1f1;
# }
# #T_ad12f_row3_col1, #T_ad12f_row15_col2 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_ad12f_row3_col2 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_ad12f_row3_col3 {
#   background-color: #50c46a;
#   color: #000000;
# }
# #T_ad12f_row3_col4 {
#   background-color: #3aba76;
#   color: #f1f1f1;
# }
# #T_ad12f_row3_col8, #T_ad12f_row9_col9 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_ad12f_row3_col9, #T_ad12f_row6_col11, #T_ad12f_row8_col9 {
#   background-color: #a2da37;
#   color: #000000;
# }
# #T_ad12f_row3_col10, #T_ad12f_row14_col7 {
#   background-color: #3c508b;
#   color: #f1f1f1;
# }
# #T_ad12f_row3_col11 {
#   background-color: #24aa83;
#   color: #f1f1f1;
# }
# #T_ad12f_row4_col0, #T_ad12f_row9_col11 {
#   background-color: #56c667;
#   color: #000000;
# }
# #T_ad12f_row4_col2, #T_ad12f_row9_col4 {
#   background-color: #b8de29;
#   color: #000000;
# }
# #T_ad12f_row4_col4 {
#   background-color: #c2df23;
#   color: #000000;
# }
# #T_ad12f_row4_col5 {
#   background-color: #dfe318;
#   color: #000000;
# }
# #T_ad12f_row4_col6 {
#   background-color: #c0df25;
#   color: #000000;
# }
# #T_ad12f_row4_col7 {
#   background-color: #b5de2b;
#   color: #000000;
# }
# #T_ad12f_row4_col8 {
#   background-color: #d5e21a;
#   color: #000000;
# }
# #T_ad12f_row4_col9 {
#   background-color: #d8e219;
#   color: #000000;
# }
# #T_ad12f_row4_col10, #T_ad12f_row5_col8 {
#   background-color: #93d741;
#   color: #000000;
# }
# #T_ad12f_row5_col0, #T_ad12f_row7_col8 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_ad12f_row5_col3 {
#   background-color: #d0e11c;
#   color: #000000;
# }
# #T_ad12f_row5_col5, #T_ad12f_row10_col2 {
#   background-color: #77d153;
#   color: #000000;
# }
# #T_ad12f_row5_col6, #T_ad12f_row10_col3, #T_ad12f_row13_col4 {
#   background-color: #98d83e;
#   color: #000000;
# }
# #T_ad12f_row5_col9 {
#   background-color: #f4e61e;
#   color: #000000;
# }
# #T_ad12f_row5_col10 {
#   background-color: #a5db36;
#   color: #000000;
# }
# #T_ad12f_row5_col11 {
#   background-color: #81d34d;
#   color: #000000;
# }
# #T_ad12f_row6_col2, #T_ad12f_row7_col7 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_ad12f_row6_col3, #T_ad12f_row8_col11 {
#   background-color: #b0dd2f;
#   color: #000000;
# }
# #T_ad12f_row6_col4 {
#   background-color: #bddf26;
#   color: #000000;
# }
# #T_ad12f_row6_col5 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_ad12f_row6_col6, #T_ad12f_row9_col3 {
#   background-color: #75d054;
#   color: #000000;
# }
# #T_ad12f_row6_col7, #T_ad12f_row10_col7 {
#   background-color: #37b878;
#   color: #f1f1f1;
# }
# #T_ad12f_row6_col8, #T_ad12f_row6_col10 {
#   background-color: #aadc32;
#   color: #000000;
# }
# #T_ad12f_row6_col9, #T_ad12f_row15_col3 {
#   background-color: #86d549;
#   color: #000000;
# }
# #T_ad12f_row7_col1 {
#   background-color: #fbe723;
#   color: #000000;
# }
# #T_ad12f_row7_col3 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_ad12f_row7_col5, #T_ad12f_row11_col10 {
#   background-color: #65cb5e;
#   color: #000000;
# }
# #T_ad12f_row7_col6 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_ad12f_row7_col10 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_ad12f_row7_col11 {
#   background-color: #2c728e;
#   color: #f1f1f1;
# }
# #T_ad12f_row8_col0 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_ad12f_row8_col1, #T_ad12f_row11_col8 {
#   background-color: #a0da39;
#   color: #000000;
# }
# #T_ad12f_row8_col3 {
#   background-color: #a8db34;
#   color: #000000;
# }
# #T_ad12f_row8_col5 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_ad12f_row8_col6 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_ad12f_row8_col8 {
#   background-color: #365d8d;
#   color: #f1f1f1;
# }
# #T_ad12f_row8_col10, #T_ad12f_row11_col6 {
#   background-color: #29af7f;
#   color: #f1f1f1;
# }
# #T_ad12f_row9_col2 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_ad12f_row9_col5 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_ad12f_row9_col7 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_ad12f_row9_col8 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_ad12f_row10_col0 {
#   background-color: #63cb5f;
#   color: #000000;
# }
# #T_ad12f_row10_col4, #T_ad12f_row10_col6 {
#   background-color: #32b67a;
#   color: #f1f1f1;
# }
# #T_ad12f_row10_col5 {
#   background-color: #1fa287;
#   color: #f1f1f1;
# }
# #T_ad12f_row10_col8 {
#   background-color: #27ad81;
#   color: #f1f1f1;
# }
# #T_ad12f_row10_col10 {
#   background-color: #42be71;
#   color: #f1f1f1;
# }
# #T_ad12f_row10_col11, #T_ad12f_row11_col2 {
#   background-color: #70cf57;
#   color: #000000;
# }
# #T_ad12f_row11_col0 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T_ad12f_row11_col4 {
#   background-color: #89d548;
#   color: #000000;
# }
# #T_ad12f_row11_col5, #T_ad12f_row12_col8 {
#   background-color: #58c765;
#   color: #000000;
# }
# #T_ad12f_row11_col7, #T_ad12f_row14_col10 {
#   background-color: #20938c;
#   color: #f1f1f1;
# }
# #T_ad12f_row12_col0 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_ad12f_row12_col2 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_ad12f_row12_col5 {
#   ba

# %%
# # look at distill_model_path
# d = r[(r.feature_space == 'qa_embedder-10') * (r.pc_components == 100)]
# d = d.groupby(cols_varied)[mets].mean()
# d.pivot_table(index=[c for c in cols_varied if not c == 'distill_model_path'],
#               columns='distill_model_path', values='corrs_test_mean', aggfunc='mean')

# %% [markdown]
# ### look at all results

# %%
d = r
# d = d[d.feature_space == 'eng1000']
# d = d[d.subject == 'UTS01']
# d = d[~(d.feature_space == 'qa_embedder-10') | (d.ndelays == 8)]
# d = d[d.feature_space == 'llama']
cols_varied = [c for c in cols_varied if not c in [
    'distill_model_path', 'feature_selection_alpha_index']]
# d = d[(d.qa_questions_version == 'v1') *
#   (d.qa_embedding_model == 'mistral 7B')]
if len(cols_varied) > 0:
    d = d.groupby(cols_varied)[mets].mean()
else:
    d = d[mets]

(
    d
    .sort_values(by='corrs_test_mean', ascending=False)
    # .sort_values(by=metric_sort, ascending=False)
    .rename(columns=lambda x: x.replace('_', ' ').replace('corrs', ''))
    .style
    .background_gradient(cmap='magma', axis=0)
    .format(precision=3)
)

# %% [markdown]
# # Compare performance of a few different models

# %%
# qa = r[(r.feature_space == 'qa_embedder-5')
# ].sort_values(by='corrs_tune_pc_mean', ascending=False).iloc[0]
qa = r.iloc[0]
eng1000 = r[(r.feature_space == 'eng1000')].sort_values(
    by='corrs_tune_pc_mean', ascending=False).iloc[0]

# %%
plt.plot(qa['corrs_test'], eng1000['corrs_test'], '.', ms=1)
plt.xlabel(f'QA Embedder (mean: {qa["corrs_test"].mean():0.3f})')
plt.ylabel(f'Eng1000 (mean: {eng1000["corrs_test"].mean():0.3f})')
plt.title('Test Correlations')
m_max = max(qa['corrs_test'].max(), eng1000['corrs_test'].max())
m_min = min(qa['corrs_test'].min(), eng1000['corrs_test'].min())
plt.plot([m_min, m_max], [m_min, m_max], 'k--')
plt.show()

# %% [markdown]
# ### Check parameters for rerunning expts (alphas, delays)

# %%
args = r[(r.pc_components == -1) * (r.ndelays == 8)].iloc[0]
args = r.sort_values(by='corrs_test_mean').iloc[-1]
model_params_to_save = joblib.load(
    join(args.save_dir_unique, 'model_params.pkl'))
print(args.feature_space, args.pc_components, args.ndelays)

# %%
# print which alphas are being used
pd.Series(model_params_to_save['alphas_best']).value_counts()

# %% [markdown]
# ### Hybrid models (use pc_components == 1 when it predicts better)

# %%
args = r[(r.pc_components == -1) * (r.feature_space == 'qa_embedder-5')
         ].sort_values(by='corrs_tune_mean', ascending=False).iloc[0]
args2 = r[(r.pc_components > 0) * (r.feature_space == 'qa_embedder-5')
          ].sort_values(by='corrs_tune_mean', ascending=False).iloc[0]
# args = r[]

# args2 = r[(r.feature_space == 'eng1000')].iloc[0]
# args = r[(r.pc_components == -1) * (r.feature_space == 8)].iloc[0]
# args = r[(r.pc_components == -1) * (r.ndelays == 8)].iloc[0]
# model_params_to_save = joblib.load(
# join(args.save_dir_unique, 'model_params.pkl'))

# %%
percentile_thresholds = np.arange(0, 100, 1)
corrs_tune_individual = args['corrs_tune']
corrs_test_individual = args['corrs_test']
corrs_test_pca = args2['corrs_test']
res = []
for percentile_threshold in percentile_thresholds:
    args_top_thresh = np.where(corrs_tune_individual > np.percentile(
        corrs_tune_individual, percentile_threshold))[0]
    args_non_top_thresh = np.where(corrs_tune_individual <= np.percentile(
        corrs_tune_individual, percentile_threshold))[0]
    args_total = np.concatenate([args_top_thresh, args_non_top_thresh])
    mean_corr_weighted = (corrs_test_individual[args_top_thresh].mean() * args_top_thresh.size +
                          corrs_test_pca[args_non_top_thresh].mean() * args_non_top_thresh.size) / args_total.size
    # print('mean corr weighted',
    #       (corrs_test_individual[args_top_thresh].mean() * args_top_thresh.size +
    #        corrs_test_pca[args_non_top_thresh].mean() * args_non_top_thresh.size) / args_total.size
    #       )
    res.append(mean_corr_weighted)
plt.plot(percentile_thresholds, res)
plt.axhline(corrs_test_individual.mean(), color='k', linestyle='--')
plt.axhline(corrs_test_pca.mean(), color='r', linestyle='--')
plt.show()
