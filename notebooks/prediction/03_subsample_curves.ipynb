# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')
from os.path import join
# import config
import numpy as np
import joblib
import seaborn as sns
import matplotlib.pyplot as plt
from neuro import analyze_helper, viz
from neuro.features.feat_select import get_alphas
import matplotlib.patches as mpatches
import dvu
import matplotlib
dvu.set_style()

# %%
# results_dir = analyze_helper.best_results_dir
# r, cols_varied, mets = analyze_helper.load_clean_results(results_dir)
# joblib.dump({'r': r, 'cols_varied': cols_varied, 'mets': mets}, 'results.pkl')
data = joblib.load('results.pkl')
r, cols_varied, mets = data['r'], data['cols_varied'], data['mets']

# %%
rr = r

# %%
r[r['qa_questions_version'] ==
    'v3_boostexamples_merged']['weight_enet_mask_num_nonzero'].value_counts()
# Out:
# weight_enet_mask_num_nonzero
# 35.0     32
# 606.0     6
# 15.0      3
# 32.0      3
# 251.0     3
# 7.0       3
# 74.0      3
# 380.0     3
# 246.0     3
# 22.0      3
# 54.0      3
# 438.0     3
# 299.0     3
# 168.0     3
# 553.0     3
# 515.0     3
# 117.0     3
# Name: count, dtype: int64

# %%
# r = rr
r = r[r.qa_questions_version.isin(['', 'v3_boostexamples_merged'])]
# r = r[r.feature_selection_alpha == -1]
r = r[~r.feature_space.isin(
    ['meta-llama/Llama-2-7b-hf', 'meta-llama/Meta-Llama-3-8B'])]
cols_varied = [c for c in cols_varied if not c in [
    'feature_selection_stability_seeds']]

r = r[r.qa_embedding_model.isin(['', 'ensemble1', 'ensemble2'])]

# only keep feature selection with stability
r = r[(r.feature_selection_alpha < 0) | (
    r.feature_selection_stability_seeds > 0)]

r.shape
# Out:
# (1034, 63)

# %% [markdown]
# ### Check runs (full grid)

# %%
d = r
# d = d[d.subject.isin(['S01', 'S02', 'S03'])]
d = d[~(d.num_stories == 15)]
# d = d[d.feature_selection_alpha < 0]
d = d[
    (d.feature_selection_alpha < 0) |
    ((d.feature_space_simplified == 'qa_embedder')
     & (d.feature_selection_alpha == get_alphas('qa_embedder')[3]))
]
d = d.groupby(cols_varied)[['corrs_test_mean']].mean()
cols_top = ['feature_space', 'embedding_layer',
            'qa_embedding_model', 'qa_questions_version', 'feature_selection_alpha']
d = (
    d.pivot_table(index=[c for c in cols_varied if not c in cols_top],
                  columns=cols_top, values='corrs_test_mean', aggfunc='mean')
    .sort_index(axis=1)
)
display(
    d.style
    .background_gradient(cmap='viridis', axis=1)
    .format(precision=3)

)
# Out:
# <style type="text/css">
# #T_f368b_row0_col0, #T_f368b_row13_col11, #T_f368b_row29_col0, #T_f368b_row30_col5, #T_f368b_row37_col10, #T_f368b_row38_col9, #T_f368b_row47_col12, #T_f368b_row55_col9 {
#   background-color: #1f988b;
#   color: #f1f1f1;
# }
# #T_f368b_row0_col1, #T_f368b_row37_col7, #T_f368b_row60_col10 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_f368b_row0_col2, #T_f368b_row39_col2, #T_f368b_row63_col1 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_f368b_row0_col3, #T_f368b_row1_col11, #T_f368b_row2_col12, #T_f368b_row3_col1, #T_f368b_row4_col1, #T_f368b_row5_col1, #T_f368b_row6_col12, #T_f368b_row7_col1, #T_f368b_row8_col1, #T_f368b_row9_col7, #T_f368b_row10_col1, #T_f368b_row11_col1, #T_f368b_row12_col1, #T_f368b_row13_col1, #T_f368b_row14_col1, #T_f368b_row15_col11, #T_f368b_row16_col1, #T_f368b_row17_col1, #T_f368b_row18_col0, #T_f368b_row19_col1, #T_f368b_row20_col1, #T_f368b_row21_col1, #T_f368b_row22_col0, #T_f368b_row23_col1, #T_f368b_row24_col0, #T_f368b_row25_col0, #T_f368b_row26_col0, #T_f368b_row27_col0, #T_f368b_row28_col2, #T_f368b_row29_col2, #T_f368b_row30_col1, #T_f368b_row31_col3, #T_f368b_row32_col2, #T_f368b_row33_col0, #T_f368b_row34_col10, #T_f368b_row35_col3, #T_f368b_row36_col0, #T_f368b_row37_col0, #T_f368b_row38_col2, #T_f368b_row39_col0, #T_f368b_row39_col7, #T_f368b_row40_col1, #T_f368b_row41_col1, #T_f368b_row42_col10, #T_f368b_row43_col1, #T_f368b_row44_col1, #T_f368b_row45_col1, #T_f368b_row46_col7, #T_f368b_row47_col1, #T_f368b_row48_col7, #T_f368b_row49_col3, #T_f368b_row50_col2, #T_f368b_row51_col0, #T_f368b_row52_col3, #T_f368b_row53_col12, #T_f368b_row54_col3, #T_f368b_row55_col1, #T_f368b_row56_col4, #T_f368b_row57_col5, #T_f368b_row58_col10, #T_f368b_row59_col5, #T_f368b_row60_col4, #T_f368b_row61_col9, #T_f368b_row62_col10, #T_f368b_row63_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_f368b_row0_col4 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_f368b_row0_col5, #T_f368b_row3_col0, #T_f368b_row42_col3 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_f368b_row0_col6, #T_f368b_row2_col6, #T_f368b_row3_col7, #T_f368b_row9_col2, #T_f368b_row57_col0, #T_f368b_row60_col5 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_f368b_row0_col7, #T_f368b_row12_col12, #T_f368b_row39_col10, #T_f368b_row60_col3 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_f368b_row0_col8, #T_f368b_row1_col4, #T_f368b_row2_col5, #T_f368b_row3_col6, #T_f368b_row4_col2, #T_f368b_row5_col4, #T_f368b_row6_col3, #T_f368b_row7_col13, #T_f368b_row8_col4, #T_f368b_row9_col12, #T_f368b_row10_col5, #T_f368b_row11_col8, #T_f368b_row12_col4, #T_f368b_row13_col8, #T_f368b_row14_col9, #T_f368b_row15_col13, #T_f368b_row16_col3, #T_f368b_row17_col4, #T_f368b_row18_col8, #T_f368b_row19_col13, #T_f368b_row20_col4, #T_f368b_row21_col13, #T_f368b_row22_col3, #T_f368b_row23_col13, #T_f368b_row24_col1, #T_f368b_row25_col13, #T_f368b_row26_col8, #T_f368b_row27_col13, #T_f368b_row28_col0, #T_f368b_row28_col11, #T_f368b_row29_col13, #T_f368b_row30_col9, #T_f368b_row31_col1, #T_f368b_row32_col4, #T_f368b_row33_col13, #T_f368b_row34_col12, #T_f368b_row35_col5, #T_f368b_row36_col8, #T_f368b_row37_col13, #T_f368b_row38_col4, #T_f368b_row39_col13, #T_f368b_row40_col9, #T_f368b_row41_col3, #T_f368b_row42_col4, #T_f368b_row43_col8, #T_f368b_row44_col8, #T_f368b_row45_col8, #T_f368b_row46_col12, #T_f368b_row47_col3, #T_f368b_row48_col12, #T_f368b_row49_col13, #T_f368b_row50_col8, #T_f368b_row51_col5, #T_f368b_row52_col6, #T_f368b_row53_col5, #T_f368b_row54_col12, #T_f368b_row55_col13, #T_f368b_row56_col1, #T_f368b_row57_col13, #T_f368b_row58_col3, #T_f368b_row59_col12, #T_f368b_row60_col12, #T_f368b_row61_col7, #T_f368b_row62_col1, #T_f368b_row63_col13 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_f368b_row0_col9, #T_f368b_row5_col11, #T_f368b_row28_col4, #T_f368b_row31_col4, #T_f368b_row41_col11, #T_f368b_row43_col7, #T_f368b_row47_col4 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_f368b_row0_col10, #T_f368b_row59_col10, #T_f368b_row63_col6 {
#   background-color: #443b84;
#   color: #f1f1f1;
# }
# #T_f368b_row0_col11, #T_f368b_row1_col5, #T_f368b_row15_col12, #T_f368b_row25_col11, #T_f368b_row32_col7, #T_f368b_row44_col0, #T_f368b_row53_col6 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_f368b_row0_col12, #T_f368b_row52_col5 {
#   background-color: #24878e;
#   color: #f1f1f1;
# }
# #T_f368b_row0_col13, #T_f368b_row1_col10, #T_f368b_row2_col13, #T_f368b_row4_col13, #T_f368b_row6_col13, #T_f368b_row8_col13, #T_f368b_row10_col13, #T_f368b_row12_col13, #T_f368b_row14_col13, #T_f368b_row16_col13, #T_f368b_row18_col13, #T_f368b_row20_col13, #T_f368b_row22_col13, #T_f368b_row24_col13, #T_f368b_row26_col13, #T_f368b_row28_col13, #T_f368b_row30_col13, #T_f368b_row32_col13, #T_f368b_row34_col13, #T_f368b_row36_col13, #T_f368b_row38_col13, #T_f368b_row40_col13, #T_f368b_row42_col13, #T_f368b_row44_col13, #T_f368b_row46_col13, #T_f368b_row48_col13, #T_f368b_row50_col13, #T_f368b_row52_col13, #T_f368b_row54_col13, #T_f368b_row56_col13, #T_f368b_row58_col13, #T_f368b_row60_col13, #T_f368b_row62_col13 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_f368b_row1_col0, #T_f368b_row10_col11, #T_f368b_row22_col12, #T_f368b_row25_col5, #T_f368b_row46_col2, #T_f368b_row46_col10 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_f368b_row1_col1, #T_f368b_row8_col10 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_f368b_row1_col2, #T_f368b_row2_col1, #T_f368b_row51_col3 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_f368b_row1_col3, #T_f368b_row3_col4, #T_f368b_row17_col13, #T_f368b_row20_col9, #T_f368b_row49_col5, #T_f368b_row61_col6 {
#   background-color: #2a768e;
#   color: #f1f1f1;
# }
# #T_f368b_row1_col6, #T_f368b_row11_col0, #T_f368b_row33_col7, #T_f368b_row61_col1 {
#   background-color: #38598c;
#   color: #f1f1f1;
# }
# #T_f368b_row1_col7, #T_f368b_row27_col12, #T_f368b_row57_col6 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_f368b_row1_col8, #T_f368b_row4_col10, #T_f368b_row9_col3, #T_f368b_row27_col5, #T_f368b_row60_col0, #T_f368b_row63_col7 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_f368b_row1_col9, #T_f368b_row51_col1, #T_f368b_row55_col3, #T_f368b_row62_col9 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_f368b_row1_col12, #T_f368b_row37_col6, #T_f368b_row47_col11 {
#   background-color: #52c569;
#   color: #000000;
# }
# #T_f368b_row1_col13, #T_f368b_row19_col10, #T_f368b_row36_col10 {
#   background-color: #50c46a;
#   color: #000000;
# }
# #T_f368b_row2_col0, #T_f368b_row5_col7, #T_f368b_row22_col1, #T_f368b_row39_col5, #T_f368b_row55_col2 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_f368b_row2_col2 {
#   background-color: #23888e;
#   color: #f1f1f1;
# }
# #T_f368b_row2_col3, #T_f368b_row23_col5, #T_f368b_row58_col11, #T_f368b_row63_col3 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_f368b_row2_col4, #T_f368b_row19_col6, #T_f368b_row35_col4, #T_f368b_row51_col2, #T_f368b_row60_col8, #T_f368b_row61_col5 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_f368b_row2_col7, #T_f368b_row6_col1 {
#   background-color: #433e85;
#   color: #f1f1f1;
# }
# #T_f368b_row2_col8, #T_f368b_row9_col5, #T_f368b_row33_col10, #T_f368b_row56_col3 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_f368b_row2_col9, #T_f368b_row10_col2, #T_f368b_row17_col6, #T_f368b_row18_col11, #T_f368b_row22_col7, #T_f368b_row32_col12, #T_f368b_row40_col3, #T_f368b_row52_col4 {
#   background-color: #98d83e;
#   color: #000000;
# }
# #T_f368b_row2_col10 {
#   background-color: #297b8e;
#   color: #f1f1f1;
# }
# #T_f368b_row2_col11, #T_f368b_row26_col3 {
#   background-color: #6ece58;
#   color: #000000;
# }
# #T_f368b_row3_col2 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_f368b_row3_col3, #T_f368b_row5_col2, #T_f368b_row16_col12, #T_f368b_row31_col11, #T_f368b_row35_col13 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_f368b_row3_col5, #T_f368b_row10_col9, #T_f368b_row15_col7, #T_f368b_row40_col11, #T_f368b_row41_col2 {
#   background-color: #70c

# %% [markdown]
# ## Check simplified table

# %%
rr.feature_space.unique()
# Out:
# array(['qa_embedder', 'meta-llama/Meta-Llama-3-70B',
#        'meta-llama/Llama-2-70b-hf', 'eng1000', 'bert-base-uncased',
#        'meta-llama/Meta-Llama-3-8B', 'meta-llama/Llama-2-7b-hf'],
#       dtype=object)

# %%
r.feature_space_simplified.unique()
# Out:
# array(['llama', 'qa_embedder', 'eng1000', 'bert-base-uncased'],
#       dtype=object)

# %%
d = r
d.num_stories = d.num_stories.replace(-1, 100)
num_stories_list = [5, 10, 20, 100]
d = d[d.num_stories.isin(num_stories_list)]
# d = d[d.num_stories == 10]
# d = d[d.subject.isin(['S01', 'S02', 'S03'])]
# d = d[~d.subject.isin(['S01', 'S02', 'S03'])]
d = d[
    (d.feature_selection_alpha < 0) |
    ((d.feature_space_simplified == 'qa_embedder')
     & (d.feature_selection_alpha == get_alphas('qa_embedder')[3]))
]
group_cols = ['subject', 'num_stories',
              'feature_space_simplified', 'feature_selection_alpha']
metric_sort = 'corrs_tune_pc_weighted_mean'
d = d.sort_values(
    by=metric_sort, ascending=False)

d = d.groupby(group_cols)[mets]
d = d.first().reset_index()
cols_top = ['feature_space_simplified', 'feature_selection_alpha']
d_tab = (
    d.pivot_table(index=[c for c in group_cols if not c in cols_top],
                  columns=cols_top, values='corrs_test_mean', aggfunc='mean')
    .sort_index(axis=1)
)
display(
    d_tab.style
    .background_gradient(cmap='magma', axis=1)
    .format(precision=3)
)
# Out:
# <style type="text/css">
# #T_4e818_row0_col0 {
#   background-color: #02020d;
#   color: #f1f1f1;
# }
# #T_4e818_row0_col1 {
#   background-color: #221150;
#   color: #f1f1f1;
# }
# #T_4e818_row0_col2, #T_4e818_row1_col1, #T_4e818_row2_col3, #T_4e818_row3_col2, #T_4e818_row4_col1, #T_4e818_row5_col1, #T_4e818_row6_col1, #T_4e818_row7_col1, #T_4e818_row8_col0, #T_4e818_row8_col1, #T_4e818_row9_col1, #T_4e818_row10_col0, #T_4e818_row11_col1, #T_4e818_row12_col0, #T_4e818_row13_col2, #T_4e818_row14_col1, #T_4e818_row15_col0, #T_4e818_row16_col2, #T_4e818_row17_col0, #T_4e818_row18_col2, #T_4e818_row19_col2, #T_4e818_row20_col1, #T_4e818_row21_col1, #T_4e818_row22_col1, #T_4e818_row23_col1, #T_4e818_row24_col4, #T_4e818_row25_col1, #T_4e818_row26_col1, #T_4e818_row27_col1, #T_4e818_row28_col2, #T_4e818_row29_col0, #T_4e818_row30_col1, #T_4e818_row31_col2 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_4e818_row0_col3, #T_4e818_row25_col3 {
#   background-color: #19103f;
#   color: #f1f1f1;
# }
# #T_4e818_row0_col4, #T_4e818_row1_col4, #T_4e818_row2_col4, #T_4e818_row3_col3, #T_4e818_row4_col4, #T_4e818_row5_col2, #T_4e818_row6_col2, #T_4e818_row7_col3, #T_4e818_row8_col4, #T_4e818_row9_col4, #T_4e818_row10_col4, #T_4e818_row11_col2, #T_4e818_row12_col4, #T_4e818_row13_col4, #T_4e818_row14_col4, #T_4e818_row15_col4, #T_4e818_row16_col1, #T_4e818_row17_col4, #T_4e818_row18_col4, #T_4e818_row19_col4, #T_4e818_row20_col3, #T_4e818_row21_col3, #T_4e818_row22_col3, #T_4e818_row23_col2, #T_4e818_row24_col0, #T_4e818_row25_col4, #T_4e818_row26_col4, #T_4e818_row27_col4, #T_4e818_row28_col1, #T_4e818_row29_col3, #T_4e818_row30_col4, #T_4e818_row31_col1 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_4e818_row1_col0 {
#   background-color: #6a1c81;
#   color: #f1f1f1;
# }
# #T_4e818_row1_col2 {
#   background-color: #fb8761;
#   color: #f1f1f1;
# }
# #T_4e818_row1_col3, #T_4e818_row24_col2 {
#   background-color: #6b1d81;
#   color: #f1f1f1;
# }
# #T_4e818_row2_col0, #T_4e818_row11_col3, #T_4e818_row16_col4 {
#   background-color: #f56b5c;
#   color: #f1f1f1;
# }
# #T_4e818_row2_col1 {
#   background-color: #2a115c;
#   color: #f1f1f1;
# }
# #T_4e818_row2_col2 {
#   background-color: #bd3977;
#   color: #f1f1f1;
# }
# #T_4e818_row3_col0 {
#   background-color: #fde7a9;
#   color: #000000;
# }
# #T_4e818_row3_col1 {
#   background-color: #491078;
#   color: #f1f1f1;
# }
# #T_4e818_row3_col4 {
#   background-color: #fcf6b8;
#   color: #000000;
# }
# #T_4e818_row4_col0 {
#   background-color: #641a80;
#   color: #f1f1f1;
# }
# #T_4e818_row4_col2 {
#   background-color: #fea571;
#   color: #000000;
# }
# #T_4e818_row4_col3, #T_4e818_row30_col2, #T_4e818_row31_col0 {
#   background-color: #29115a;
#   color: #f1f1f1;
# }
# #T_4e818_row5_col0 {
#   background-color: #e04c67;
#   color: #f1f1f1;
# }
# #T_4e818_row5_col3 {
#   background-color: #57157e;
#   color: #f1f1f1;
# }
# #T_4e818_row5_col4 {
#   background-color: #fcf9bb;
#   color: #000000;
# }
# #T_4e818_row6_col0 {
#   background-color: #ab337c;
#   color: #f1f1f1;
# }
# #T_4e818_row6_col3, #T_4e818_row7_col0 {
#   background-color: #e75263;
#   color: #f1f1f1;
# }
# #T_4e818_row6_col4 {
#   background-color: #f9785d;
#   color: #f1f1f1;
# }
# #T_4e818_row7_col2, #T_4e818_row13_col0, #T_4e818_row19_col1 {
#   background-color: #8b2981;
#   color: #f1f1f1;
# }
# #T_4e818_row7_col4 {
#   background-color: #d5446d;
#   color: #f1f1f1;
# }
# #T_4e818_row8_col2, #T_4e818_row10_col3, #T_4e818_row11_col0 {
#   background-color: #f7725c;
#   color: #f1f1f1;
# }
# #T_4e818_row8_col3 {
#   background-color: #862781;
#   color: #f1f1f1;
# }
# #T_4e818_row9_col0 {
#   background-color: #7c2382;
#   color: #f1f1f1;
# }
# #T_4e818_row9_col2 {
#   background-color: #f4675c;
#   color: #f1f1f1;
# }
# #T_4e818_row9_col3 {
#   background-color: #52137c;
#   color: #f1f1f1;
# }
# #T_4e818_row10_col1 {
#   background-color: #6d1d81;
#   color: #f1f1f1;
# }
# #T_4e818_row10_col2, #T_4e818_row15_col1 {
#   background-color: #fec88c;
#   color: #000000;
# }
# #T_4e818_row11_col4 {
#   background-color: #a8327d;
#   color: #f1f1f1;
# }
# #T_4e818_row12_col1 {
#   background-color: #271258;
#   color: #f1f1f1;
# }
# #T_4e818_row12_col2 {
#   background-color: #130d34;
#   color: #f1f1f1;
# }
# #T_4e818_row12_col3 {
#   background-color: #420f75;
#   color: #f1f1f1;
# }
# #T_4e818_row13_col1 {
#   background-color: #51127c;
#   color: #f1f1f1;
# }
# #T_4e818_row13_col3 {
#   background-color: #02020b;
#   color: #f1f1f1;
# }
# #T_4e818_row14_col0, #T_4e818_row27_col0 {
#   background-color: #451077;
#   color: #f1f1f1;
# }
# #T_4e818_row14_col2, #T_4e818_row21_col2 {
#   background-color: #feb97f;
#   color: #000000;
# }
# #T_4e818_row14_col3 {
#   background-color: #b0357b;
#   color: #f1f1f1;
# }
# #T_4e818_row15_col2 {
#   background-color: #db476a;
#   color: #f1f1f1;
# }
# #T_4e818_row15_col3, #T_4e818_row20_col0, #T_4e818_row25_col2 {
#   background-color: #f4695c;
#   color: #f1f1f1;
# }
# #T_4e818_row16_col0, #T_4e818_row20_col4 {
#   background-color: #c83e73;
#   color: #f1f1f1;
# }
# #T_4e818_row16_col3 {
#   background-color: #ca3e72;
#   color: #f1f1f1;
# }
# #T_4e818_row17_col1 {
#   background-color: #c53c74;
#   color: #f1f1f1;
# }
# #T_4e818_row17_col2 {
#   background-color: #9c2e7f;
#   color: #f1f1f1;
# }
# #T_4e818_row17_col3 {
#   background-color: #d3436e;
#   color: #f1f1f1;
# }
# #T_4e818_row18_col0 {
#   background-color: #601880;
#   color: #f1f1f1;
# }
# #T_4e818_row18_col1 {
#   background-color: #8c2981;
#   color: #f1f1f1;
# }
# #T_4e818_row18_col3, #T_4e818_row30_col0 {
#   background-color: #792282;
#   color: #f1f1f1;
# }
# #T_4e818_row19_col0 {
#   background-color: #20114b;
#   color: #f1f1f1;
# }
# #T_4e818_row19_col3 {
#   background-color: #892881;
#   color: #f1f1f1;
# }
# #T_4e818_row20_col2 {
#   background-color: #fed799;
#   color: #000000;
# }
# #T_4e818_row21_col0 {
#   background-color: #7e2482;
#   color: #f1f1f1;
# }
# #T_4e818_row21_col4 {
#   background-color: #fb8560;
#   color: #f1f1f1;
# }
# #T_4e818_row22_col0 {
#   background-color: #942c80;
#   color: #f1f1f1;
# }
# #T_4e818_row22_col2, #T_4e818_row23_col3 {
#   background-color: #fdebac;
#   color: #000000;
# }
# #T_4e818_row22_col4 {
#   background-color: #fecd90;
#   color: #000000;
# }
# #T_4e818_row23_col0 {
#   background-color: #fc8c63;
#   color: #f1f1f1;
# }
# #T_4e818_row23_col4 {
#   background-color: #fc8e64;
#   color: #000000;
# }
# #T_4e818_row24_col1 {
#   background-color: #040414;
#   color: #f1f1f1;
# }
# #T_4e818_row24_col3 {
#   background-color: #030312;
#   color: #f1f1f1;
# }
# #T_4e818_row25_col0 {
#   background-color: #150e38;
#   color: #f1f1f1;
# }
# #T_4e818_row26_col0 {
#   background-color: #cd4071;
#   color: #f1f1f1;
# }
# #T_4e818_row26_col2 {
#   background-color: #651a80;
#   color: #f1f1f1;
# }
# #T_4e818_row26_col3 {
#   background-color: #feb47b;
#   color: #000000;
# }
# #T_4e818_row27_col2 {
#   background-color: #a02f7f;
#   color: #f1f1f1;
# }
# #T_4e818_row27_col3 {
#   background-color: #fe9d6c;
#   color: #000000;
# }
# #T_4e818_row28_col0, #T_4e818_row29_col2 {
#   background-color: #bf3a77;
#   color: #f1f1f1;
# }
# #T_4e818_row28_col3 {
#   background-color: #fec185;
#   color: #000000;
# }
# #T_4e818_row28_col4 {
#   background-color: #fde0a1;
#   color: #000000;
# }
# #T_4e818_row29_col1 {
#   background-color: #331067;
#   color: #f1f1f1;
# }
# #T_4e818_row29_col4 {
#   background-color: #7b2382;
#   color: #f1f1f1;
# }
# #T_4e818_row30_col3 {
#   background-color: #d8456c;
#   color: #f1f1f1;
# }
# #T_4e818_row31_col3 {
#   background-color: #ad347c;
#   color: #f1f1f1;
# }
# #T_4e818_row31_col4 {
#   background-color: #fddc9e;
#   color: #000000;
# }
# </style>
# <table id="T_4e818">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >feature_space_simplified</th>
#       <th id="T_4e818_level0_col0" class="col_heading level0 col0" >bert-base-uncased</th>
#       <th id="T_4e818_level0_col1" class="col_heading level0 col1" >eng1000</th>
#       <th id="T_4e818_level0_col2" class="col_heading level0 col2" >llama</th>
#       <th id="T_4e818_level0_col3" class="col_heading level0 col3" colspan="2">qa_embedder</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >feature_selection_alpha</th>
#       <th id="T_4e818_level1_col0" class="col_heading level1 col0" >-1.000000</th>
#       <th id="T_4e818_level1_col1" class="col_heading level1 col1" >-1.000000</th>
#       <th id="T_4e818_level1

# %%
val_all_qa_100 = d_tab[('qa_embedder', 0.28)][np.array([x[1]
                                                        for x in d_tab.index]) == 100].mean()
val_all_llama_100 = d_tab[('llama', -1.0)][np.array([x[1]
                                                     for x in d_tab.index]) == 100].mean()
print(f'val_all_qa_100: {val_all_qa_100:.3f} val_all_llama_100: {val_all_llama_100:.3f} improvement: {(val_all_qa_100 - val_all_llama_100) / val_all_llama_100:.2%}')

val_all_qa_10 = d_tab[('qa_embedder', 0.28)][np.array([x[1]
                                                       for x in d_tab.index]) == 5].mean()
val_all_llama_10 = d_tab[('llama', -1.0)][np.array([x[1]
                                                    for x in d_tab.index]) == 5].mean()
print(f'val_all_qa_10: {val_all_qa_10:.3f} val_all_llama_10: {val_all_llama_10:.3f} improvement: {(val_all_qa_10 - val_all_llama_10) / val_all_llama_10:.2%}')
# Out:
# val_all_qa_100: 0.056 val_all_llama_100: 0.050 improvement: 12.02%
# val_all_qa_10: 0.022 val_all_llama_10: 0.015 improvement: 43.30%

# %%
# plot
d['legend'] = list(
    zip(d.feature_space_simplified.map(viz.feature_space_rename), d.feature_selection_alpha))
# ('BERT', -1.0), ('Eng1000', -1.0), ('LLaMA', -1.0),
#    ('QA-Emb', -1.0), ('QA-Emb', 0.28)
d['legend'] = d['legend'].map(lambda x: {
    ('BERT', -1.0): 'BERT',
    ('Eng1000', -1.0): 'Eng1000',
    ('LLaMA', -1.0): 'LLaMA (best)',
    ('QA-Emb', -1.0): 'QA',
    ('QA-Emb', 0.28): 'QA (35 questions)'
}.get(x, x))
kwargs = dict(
    x='num_stories',
    y='corrs_test_mean',
    hue='legend',
    hue_order=['Eng1000', 'BERT', 'LLaMA (best)', 'QA', 'QA (35 questions)'],
    palette=['tomato', '#aaa', '#000', 'C0', 'cadetblue'],
    dodge=True,
)
# sns.boxplot(**kwargs, fill=False)
# fig = plt.figure(figsize=(12, 6))
matplotlib.rcParams.update({'font.size': 14})
plt.figure(dpi=300, figsize=(8, 4))
ax = sns.barplot(**kwargs, data=d, alpha=0.2, errorbar='se',
                 err_kws={'alpha': 0.4}, legend=False)
sns.stripplot(
    **kwargs, data=d[d.subject.isin(['S01', 'S02', 'S03'])], jitter=True, size=4, legend=False)
# sns.stripplot(**kwargs, jitter=True, size=4)
sns.stripplot(
    **kwargs, data=d[~d.subject.isin(['S01', 'S02', 'S03'])], jitter=True, size=4)

# ylim bottom to 0
plt.ylim(bottom=0)

# replace "100" with "All" on xticklabels
xtick_labels = ax.get_xticklabels()
ax.set_xticklabels(['All' if label.get_text() ==
                   '100' else label.get_text() for label in xtick_labels])

plt.xlabel("Number of stories used for training")
plt.ylabel("Test correlation")

# plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(loc='upper left')  # , bbox_to_anchor=(1, 0.5))
plt.savefig('../qa_results/figs/subsample_barplot.pdf', bbox_inches='tight')
plt.savefig('../qa_results/figs/subsample_barplot.png',
            bbox_inches='tight', dpi=500)
plt.show()
# Out:
# /tmp/ipykernel_2201942/1339472530.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['All' if label.get_text() ==

# %% [markdown]
# ### Plot for talk

# %%
d.num_stories.unique()
# Out:
# array([  5,  10,  20, 100])

# %%
# plot
dp = d[d.num_stories.isin([5, 100])]
dp['legend'] = list(
    zip(dp.feature_space_simplified.map(viz.feature_space_rename), dp.feature_selection_alpha))
# ('BERT', -1.0), ('Eng1000', -1.0), ('LLaMA', -1.0),
#    ('QA-Emb', -1.0), ('QA-Emb', 0.28)
dp['legend'] = dp['legend'].map(lambda x: {
    ('BERT', -1.0): 'BERT',
    ('Eng1000', -1.0): 'Eng1000',
    ('LLaMA', -1.0): 'LLaMA (best)',
    ('QA-Emb', -1.0): 'QA',
    ('QA-Emb', 0.28): 'QA (35 questions)'
}.get(x, x))
kwargs = dict(
    x='num_stories',
    y='corrs_test_mean',
    hue='legend',
    hue_order=['Eng1000', 'BERT', 'LLaMA (best)', 'QA', 'QA (35 questions)'],
    palette=['tomato', '#aaa', '#000', 'C0', 'navy'],
    dodge=True,
)
# sns.boxplot(**kwargs, fill=False)
# fig = plt.figure(figsize=(12, 6))
matplotlib.rcParams.update({'font.size': 14})
plt.figure(dpi=300, figsize=(8, 4))
ax = sns.barplot(**kwargs, data=dp, legend=True, errorbar=None)
plt.ylim(bottom=0)

xtick_labels = ax.get_xticklabels()
ax.set_xticklabels(['All' if label.get_text() ==
                   '100' else label.get_text() for label in xtick_labels])

plt.xlabel("Number of stories used for training")
plt.ylabel("Predictive performance")

# plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(loc='upper left')  # , bbox_to_anchor=(1, 0.5))
plt.savefig('../qa_results/figs/subsample_barplot.pdf', bbox_inches='tight')
plt.savefig('../qa_results/figs/subsample_barplot.png',
            bbox_inches='tight', dpi=500)
plt.show()
# Out:
# /tmp/ipykernel_2201942/798614940.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp['legend'] = list(
# /tmp/ipykernel_2201942/798614940.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp['legend'] = dp['legend'].map(lambda x: {
# /tmp/ipykernel_2201942/798614940.py:30: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['All' if label.get_text() ==

# %%
num_stories_list = [5, 10, 20, 100]
dt = d_tab.reset_index()
for i, num_stories in enumerate(num_stories_list):
    dn = dt[dt.num_stories == num_stories]
    # display(dn)
    print(f'num_stories = {num_stories}')
    display(dn.drop(columns=['num_stories']).style.background_gradient(
        cmap='magma', axis=1).format(precision=3))
# Out:
# num_stories = 5
# /tmp/ipykernel_2201942/1032307835.py:7: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   display(dn.drop(columns=['num_stories']).style.background_gradient(
# <style type="text/css">
# #T_c960f_row0_col1 {
#   background-color: #02020d;
#   color: #f1f1f1;
# }
# #T_c960f_row0_col2 {
#   background-color: #221150;
#   color: #f1f1f1;
# }
# #T_c960f_row0_col3, #T_c960f_row1_col2, #T_c960f_row2_col1, #T_c960f_row2_col2, #T_c960f_row3_col1, #T_c960f_row4_col3, #T_c960f_row5_col2, #T_c960f_row6_col5, #T_c960f_row7_col3 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_c960f_row0_col4 {
#   background-color: #19103f;
#   color: #f1f1f1;
# }
# #T_c960f_row0_col5, #T_c960f_row1_col5, #T_c960f_row2_col5, #T_c960f_row3_col5, #T_c960f_row4_col2, #T_c960f_row5_col4, #T_c960f_row6_col1, #T_c960f_row7_col2 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_c960f_row1_col1 {
#   background-color: #641a80;
#   color: #f1f1f1;
# }
# #T_c960f_row1_col3 {
#   background-color: #fea571;
#   color: #000000;
# }
# #T_c960f_row1_col4 {
#   background-color: #29115a;
#   color: #f1f1f1;
# }
# #T_c960f_row2_col3 {
#   background-color: #f7725c;
#   color: #f1f1f1;
# }
# #T_c960f_row2_col4 {
#   background-color: #862781;
#   color: #f1f1f1;
# }
# #T_c960f_row3_col2 {
#   background-color: #271258;
#   color: #f1f1f1;
# }
# #T_c960f_row3_col3 {
#   background-color: #130d34;
#   color: #f1f1f1;
# }
# #T_c960f_row3_col4 {
#   background-color: #420f75;
#   color: #f1f1f1;
# }
# #T_c960f_row4_col1, #T_c960f_row5_col5 {
#   background-color: #c83e73;
#   color: #f1f1f1;
# }
# #T_c960f_row4_col4 {
#   background-color: #ca3e72;
#   color: #f1f1f1;
# }
# #T_c960f_row4_col5 {
#   background-color: #f56b5c;
#   color: #f1f1f1;
# }
# #T_c960f_row5_col1 {
#   background-color: #f4695c;
#   color: #f1f1f1;
# }
# #T_c960f_row5_col3 {
#   background-color: #fed799;
#   color: #000000;
# }
# #T_c960f_row6_col2 {
#   background-color: #040414;
#   color: #f1f1f1;
# }
# #T_c960f_row6_col3 {
#   background-color: #6b1d81;
#   color: #f1f1f1;
# }
# #T_c960f_row6_col4 {
#   background-color: #030312;
#   color: #f1f1f1;
# }
# #T_c960f_row7_col1 {
#   background-color: #bf3a77;
#   color: #f1f1f1;
# }
# #T_c960f_row7_col4 {
#   background-color: #fec185;
#   color: #000000;
# }
# #T_c960f_row7_col5 {
#   background-color: #fde0a1;
#   color: #000000;
# }
# </style>
# <table id="T_c960f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >feature_space_simplified</th>
#       <th id="T_c960f_level0_col0" class="col_heading level0 col0" >subject</th>
#       <th id="T_c960f_level0_col1" class="col_heading level0 col1" >bert-base-uncased</th>
#       <th id="T_c960f_level0_col2" class="col_heading level0 col2" >eng1000</th>
#       <th id="T_c960f_level0_col3" class="col_heading level0 col3" >llama</th>
#       <th id="T_c960f_level0_col4" class="col_heading level0 col4" colspan="2">qa_embedder</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >feature_selection_alpha</th>
#       <th id="T_c960f_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_c960f_level1_col1" class="col_heading level1 col1" >-1.000000</th>
#       <th id="T_c960f_level1_col2" class="col_heading level1 col2" >-1.000000</th>
#       <th id="T_c960f_level1_col3" class="col_heading level1 col3" >-1.000000</th>
#       <th id="T_c960f_level1_col4" class="col_heading level1 col4" >-1.000000</th>
#       <th id="T_c960f_level1_col5" class="col_heading level1 col5" >0.280000</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c960f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c960f_row0_col0" class="data row0 col0" >S01</td>
#       <td id="T_c960f_row0_col1" class="data row0 col1" >0.009</td>
#       <td id="T_c960f_row0_col2" class="data row0 col2" >0.010</td>
#       <td id="T_c960f_row0_col3" class="data row0 col3" >0.009</td>
#       <td id="T_c960f_row0_col4" class="data row0 col4" >0.010</td>
#       <td id="T_c960f_row0_col5" class="data row0 col5" >0.017</td>
#     </tr>
#     <tr>
#       <th id="T_c960f_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_c960f_row1_col0" class="data row1 col0" >S02</td>
#       <td id="T_c960f_row1_col1" class="data row1 col1" >0.023</td>
#       <td id="T_c960f_row1_col2" class="data row1 col2" >0.015</td>
#       <td id="T_c960f_row1_col3" class="data row1 col3" >0.037</td>
#       <td id="T_c960f_row1_col4" class="data row1 col4" >0.019</td>
#       <td id="T_c960f_row1_col5" class="data row1 col5" >0.042</td>
#     </tr>
#     <tr>
#       <th id="T_c960f_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_c960f_row2_col0" class="data row2 col0" >S03</td>
#       <td id="T_c960f_row2_col1" class="data row2 col1" >0.025</td>
#       <td id="T_c960f_row2_col2" class="data row2 col2" >0.025</td>
#       <td id="T_c960f_row2_col3" class="data row2 col3" >0.050</td>
#       <td id="T_c960f_row2_col4" class="data row2 col4" >0.038</td>
#       <td id="T_c960f_row2_col5" class="data row2 col5" >0.060</td>
#     </tr>
#     <tr>
#       <th id="T_c960f_level0_row3" class="row_heading level0 row3" >12</th>
#       <td id="T_c960f_row3_col0" class="data row3 col0" >S04</td>
#       <td id="T_c960f_row3_col1" class="data row3 col1" >0.001</td>
#       <td id="T_c960f_row3_col2" class="data row3 col2" >0.005</td>
#       <td id="T_c960f_row3_col3" class="data row3 col3" >0.003</td>
#       <td id="T_c960f_row3_col4" class="data row3 col4" >0.006</td>
#       <td id="T_c960f_row3_col5" class="data row3 col5" >0.027</td>
#     </tr>
#     <tr>
#       <th id="T_c960f_level0_row4" class="row_heading level0 row4" >16</th>
#       <td id="T_c960f_row4_col0" class="data row4 col0" >S05</td>
#       <td id="T_c960f_row4_col1" class="data row4 col1" >0.004</td>
#       <td id="T_c960f_row4_col2" class="data row4 col2" >0.009</td>
#       <td id="T_c960f_row4_col3" class="data row4 col3" >-0.001</td>
#       <td id="T_c960f_row4_col4" class="data row4 col4" >0.005</td>
#       <td id="T_c960f_row4_col5" class="data row4 col5" >0.006</td>
#     </tr>
#     <tr>
#       <th id="T_c960f_level0_row5" class="row_heading level0 row5" >20</th>
#       <td id="T_c960f_row5_col0" class="data row5 col0" >S06</td>
#       <td id="T_c960f_row5_col1" class="data row5 col1" >0.012</td>
#       <td id="T_c960f_row5_col2" class="data row5 col2" >0.001</td>
#       <td id="T_c960f_row5_col3" class="data row5 col3" >0.016</td>
#       <td id="T_c960f_row5_col4" class="data row5 col4" >0.017</td>
#       <td id="T_c960f_row5_col5" class="data row5 col5" >0.010</td>
#     </tr>
#     <tr>
#       <th id="T_c960f_level0_row6" class="row_heading level0 row6" >24</th>
#       <td id="T_c960f_row6_col0" class="data row6 col0" >S07</td>
#       <td id="T_c960f_row6_col1" class="data row6 col1" >0.014</td>
#       <td id="T_c960f_row6_col2" class="data row6 col2" >0.010</td>
#       <td id="T_c960f_row6_col3" class="data row6 col3" >0.011</td>
#       <td id="T_c960f_row6_col4" class="data row6 col4" >0.010</td>
#       <td id="T_c960f_row6_col5" class="data row6 col5" >0.010</td>
#     </tr>
#     <tr>
#       <th id="T_c960f_level0_row7" class="row_heading level0 row7" >28</th>
#       <td id="T_c960f_row7_col0" class="data row7 col0" >S08</td>
#       <td id="T_c960f_row7_col1" class="data row7 col1" >0.000</td>
#       <td id="T_c960f_row7_col2" class="data row7 col2" >0.003</td>
#       <td id="T_c960f_row7_col3" class="data row7 col3" >-0.003</td>
#       <td id="T_c960f_row7_col4" class="data row7 col4" >0.002</td>
#       <td id="T_c960f_row7_col5" class="data row7 col5" >0.003</td>
#     </tr>
#   </tbody>
# </table>
# num_stories = 10
# /tmp/ipykernel_2201942/1032307835.py:7: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   display(dn.drop(columns=['num_stories']).style.background_gradient(
# <style type="text/css">
# #T_563b8_row0_col1 {
#   background-color: #6a1c81;
#   color: #f1f1f1;
# }
# #T_563b8_row0_col2, #T_563b8_row1_col2, #T_563b8_row2_col2, #T_563b8_row3_col3, #T_563b8_row4_col1, #T_563b8_row5_col2, #T_563b8_row6_col2, #T_563b8_row7_col1 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_563b8_row0_col3 {
#   background-color: #fb8761;
#   color: #f1f1f1;
# }
# #T_563b8_row0_col4 {
#   background-color: #6b1d81;
#   color: #f1f1f1;
# }
# #T_563b8_row0_col5, #T_563b8_row1_col3, #T_563b8_row2_col5, #T_563b8_row3_col5, #T_563b8_row4_col5, #T_563b8_row5_col4, #T_563b8_row6_col5, #T_563b8_row7_col4 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_563b8_row1_col1 {
#   background-color: #e04c67;
#   color: #f1f1f1;
# }
# #T_563b8_row1_col4 {
#   background-color: #57157e;
#   color: #f1f1f1;
# }
# #T_563b8_row1_col5 {
#   background-color: #fcf9bb;
#   color: #000000;
# }
# #T_563b8_row2_col1 {
#   background-color: #7c2382;
#   color: #f1f1f1;
# }
# #T_563b8_row2_col3 {
#   background-color: #f4675c;
#   color: #f1f1f1;
# }
# #T_563b8_row2_col4 {
#   background-color: #52137c;
#   color: #f1f1f1;
# }
# #T_563b8_row3_col1 {
#   background-color: #8b2981;
#   color: #f1f1f1;
# }
# #T_563b8_row3_col2 {
#   background-color: #51127c;
#   color: #f1f1f1;
# }
# #T_563b8_row3_col4 {
#   background-color: #02020b;
#   color: #f1f1f1;
# }
# #T_563b8_row4_col2 {
#   background-color: #c53c74;
#   color: #f1f1f1;
# }
# #T_563b8_row4_col3 {
#   background-color: #9c2e7f;
#   color: #f1f1f1;
# }
# #T_563b8_row4_col4 {
#   background-color: #d3436e;
#   color: #f1f1f1;
# }
# #T_563b8_row5_col1 {
#   background-color: #7e2482;
#   color: #f1f1f1;
# }
# #T_563b8_row5_col3 {
#   background-color: #feb97f;
#   color: #000000;
# }
# #T_563b8_row5_col5 {
#   background-color: #fb8560;
#   color: #f1f1f1;
# }
# #T_563b8_row6_col1 {
#   background-color: #150e38;
#   color: #f1f1f1;
# }
# #T_563b8_row6_col3 {
#   background-color: #f4695c;
#   color: #f1f1f1;
# }
# #T_563b8_row6_col4 {
#   background-color: #19103f;
#   color: #f1f1f1;
# }
# #T_563b8_row7_col2 {
#   background-color: #331067;
#   color: #f1f1f1;
# }
# #T_563b8_row7_col3 {
#   background-color: #bf3a77;
#   color: #f1f1f1;
# }
# #T_563b8_row7_col5 {
#   background-color: #7b2382;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_563b8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >feature_space_simplified</th>
#       <th id="T_563b8_level0_col0" class="col_heading level0 col0" >subject</th>
#       <th id="T_563b8_level0_col1" class="col_heading level0 col1" >bert-base-uncased</th>
#       <th id="T_563b8_level0_col2" class="col_heading level0 col2" >eng1000</th>
#       <th id="T_563b8_level0_col3" class="col_heading level0 col3" >llama</th>
#       <th id="T_563b8_level0_col4" class="col_heading level0 col4" colspan="2">qa_embedder</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >feature_selection_alpha</th>
#       <th id="T_563b8_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_563b8_level1_col1" class="col_heading level1 col1" >-1.000000</th>
#       <th id="T_563b8_level1_col2" class="col_heading level1 col2" >-1.000000</th>
#       <th id="T_563b8_level1_col3" class="col_heading level1 col3" >-1.000000</th>
#       <th id="T_563b8_level1_col4" class="col_heading level1 col4" >-1.000000</th>
#       <th id="T_563b8_level1_col5" class="col_heading level1 col5" >0.280000</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_563b8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_563b8_row0_col0" class="data row0 col0" >S01</td>
#       <td id="T_563b8_row0_col1" class="data row0 col1" >0.010</td>
#       <td id="T_563b8_row0_col2" class="data row0 col2" >0.005</td>
#       <td id="T_563b8_row0_col3" class="data row0 col3" >0.017</td>
#       <td id="T_563b8_row0_col4" class="data row0 col4" >0.010</td>
#       <td id="T_563b8_row0_col5" class="data row0 col5" >0.021</td>
#     </tr>
#     <tr>
#       <th id="T_563b8_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_563b8_row1_col0" class="data row1 col0" >S02</td>
#       <td id="T_563b8_row1_col1" class="data row1 col1" >0.034</td>
#       <td id="T_563b8_row1_col2" class="data row1 col2" >0.021</td>
#       <td id="T_563b8_row1_col3" class="data row1 col3" >0.043</td>
#       <td id="T_563b8_row1_col4" class="data row1 col4" >0.027</td>
#       <td id="T_563b8_row1_col5" class="data row1 col5" >0.043</td>
#     </tr>
#     <tr>
#       <th id="T_563b8_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_563b8_row2_col0" class="data row2 col0" >S03</td>
#       <td id="T_563b8_row2_col1" class="data row2 col1" >0.043</td>
#       <td id="T_563b8_row2_col2" class="data row2 col2" >0.021</td>
#       <td id="T_563b8_row2_col3" class="data row2 col3" >0.061</td>
#       <td id="T_563b8_row2_col4" class="data row2 col4" >0.036</td>
#       <td id="T_563b8_row2_col5" class="data row2 col5" >0.080</td>
#     </tr>
#     <tr>
#       <th id="T_563b8_level0_row3" class="row_heading level0 row3" >13</th>
#       <td id="T_563b8_row3_col0" class="data row3 col0" >S04</td>
#       <td id="T_563b8_row3_col1" class="data row3 col1" >0.016</td>
#       <td id="T_563b8_row3_col2" class="data row3 col2" >0.011</td>
#       <td id="T_563b8_row3_col3" class="data row3 col3" >0.002</td>
#       <td id="T_563b8_row3_col4" class="data row3 col4" >0.003</td>
#       <td id="T_563b8_row3_col5" class="data row3 col5" >0.038</td>
#     </tr>
#     <tr>
#       <th id="T_563b8_level0_row4" class="row_heading level0 row4" >17</th>
#       <td id="T_563b8_row4_col0" class="data row4 col0" >S05</td>
#       <td id="T_563b8_row4_col1" class="data row4 col1" >-0.006</td>
#       <td id="T_563b8_row4_col2" class="data row4 col2" >0.008</td>
#       <td id="T_563b8_row4_col3" class="data row4 col3" >0.006</td>
#       <td id="T_563b8_row4_col4" class="data row4 col4" >0.009</td>
#       <td id="T_563b8_row4_col5" class="data row4 col5" >0.020</td>
#     </tr>
#     <tr>
#       <th id="T_563b8_level0_row5" class="row_heading level0 row5" >21</th>
#       <td id="T_563b8_row5_col0" class="data row5 col0" >S06</td>
#       <td id="T_563b8_row5_col1" class="data row5 col1" >0.005</td>
#       <td id="T_563b8_row5_col2" class="data row5 col2" >-0.002</td>
#       <td id="T_563b8_row5_col3" class="data row5 col3" >0.016</td>
#       <td id="T_563b8_row5_col4" class="data row5 col4" >0.019</td>
#       <td id="T_563b8_row5_col5" class="data row5 col5" >0.014</td>
#     </tr>
#     <tr>
#       <th id="T_563b8_level0_row6" class="row_heading level0 row6" >25</th>
#       <td id="T_563b8_row6_col0" class="data row6 col0" >S07</td>
#       <td id="T_563b8_row6_col1" class="data row6 col1" >0.010</td>
#       <td id="T_563b8_row6_col2" class="data row6 col2" >0.009</td>
#       <td id="T_563b8_row6_col3" class="data row6 col3" >0.015</td>
#       <td id="T_563b8_row6_col4" class="data row6 col4" >0.010</td>
#       <td id="T_563b8_row6_col5" class="data row6 col5" >0.017</td>
#     </tr>
#     <tr>
#       <th id="T_563b8_level0_row7" class="row_heading level0 row7" >29</th>
#       <td id="T_563b8_row7_col0" class="data row7 col0" >S08</td>
#       <td id="T_563b8_row7_col1" class="data row7 col1" >0.001</td>
#       <td id="T_563b8_row7_col2" class="data row7 col2" >0.003</td>
#       <td id="T_563b8_row7_col3" class="data row7 col3" >0.007</td>
#       <td id="T_563b8_row7_col4" class="data row7 col4" >0.013</td>
#       <td id="T_563b8_row7_col5" class="data row7 col5" >0.005</td>
#     </tr>
#   </tbody>
# </table>
# num_stories = 20
# /tmp/ipykernel_2201942/1032307835.py:7: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   display(dn.drop(columns=['num_stories']).style.background_gradient(
# <style type="text/css">
# #T_5b97d_row0_col1 {
#   background-color: #f56b5c;
#   color: #f1f1f1;
# }
# #T_5b97d_row0_col2 {
#   background-color: #2a115c;
#   color: #f1f1f1;
# }
# #T_5b97d_row0_col3 {
#   background-color: #bd3977;
#   color: #f1f1f1;
# }
# #T_5b97d_row0_col4, #T_5b97d_row1_col2, #T_5b97d_row2_col1, #T_5b97d_row3_col2, #T_5b97d_row4_col3, #T_5b97d_row5_col2, #T_5b97d_row6_col2, #T_5b97d_row7_col2 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_5b97d_row0_col5, #T_5b97d_row1_col3, #T_5b97d_row2_col5, #T_5b97d_row3_col5, #T_5b97d_row4_col5, #T_5b97d_row5_col4, #T_5b97d_row6_col5, #T_5b97d_row7_col5 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_5b97d_row1_col1 {
#   background-color: #ab337c;
#   color: #f1f1f1;
# }
# #T_5b97d_row1_col4 {
#   background-color: #e75263;
#   color: #f1f1f1;
# }
# #T_5b97d_row1_col5 {
#   background-color: #f9785d;
#   color: #f1f1f1;
# }
# #T_5b97d_row2_col2 {
#   background-color: #6d1d81;
#   color: #f1f1f1;
# }
# #T_5b97d_row2_col3 {
#   background-color: #fec88c;
#   color: #000000;
# }
# #T_5b97d_row2_col4 {
#   background-color: #f7725c;
#   color: #f1f1f1;
# }
# #T_5b97d_row3_col1 {
#   background-color: #451077;
#   color: #f1f1f1;
# }
# #T_5b97d_row3_col3 {
#   background-color: #feb97f;
#   color: #000000;
# }
# #T_5b97d_row3_col4 {
#   background-color: #b0357b;
#   color: #f1f1f1;
# }
# #T_5b97d_row4_col1 {
#   background-color: #601880;
#   color: #f1f1f1;
# }
# #T_5b97d_row4_col2 {
#   background-color: #8c2981;
#   color: #f1f1f1;
# }
# #T_5b97d_row4_col4, #T_5b97d_row7_col1 {
#   background-color: #792282;
#   color: #f1f1f1;
# }
# #T_5b97d_row5_col1 {
#   background-color: #942c80;
#   color: #f1f1f1;
# }
# #T_5b97d_row5_col3 {
#   background-color: #fdebac;
#   color: #000000;
# }
# #T_5b97d_row5_col5 {
#   background-color: #fecd90;
#   color: #000000;
# }
# #T_5b97d_row6_col1 {
#   background-color: #cd4071;
#   color: #f1f1f1;
# }
# #T_5b97d_row6_col3 {
#   background-color: #651a80;
#   color: #f1f1f1;
# }
# #T_5b97d_row6_col4 {
#   background-color: #feb47b;
#   color: #000000;
# }
# #T_5b97d_row7_col3 {
#   background-color: #29115a;
#   color: #f1f1f1;
# }
# #T_5b97d_row7_col4 {
#   background-color: #d8456c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5b97d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >feature_space_simplified</th>
#       <th id="T_5b97d_level0_col0" class="col_heading level0 col0" >subject</th>
#       <th id="T_5b97d_level0_col1" class="col_heading level0 col1" >bert-base-uncased</th>
#       <th id="T_5b97d_level0_col2" class="col_heading level0 col2" >eng1000</th>
#       <th id="T_5b97d_level0_col3" class="col_heading level0 col3" >llama</th>
#       <th id="T_5b97d_level0_col4" class="col_heading level0 col4" colspan="2">qa_embedder</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >feature_selection_alpha</th>
#       <th id="T_5b97d_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_5b97d_level1_col1" class="col_heading level1 col1" >-1.000000</th>
#       <th id="T_5b97d_level1_col2" class="col_heading level1 col2" >-1.000000</th>
#       <th id="T_5b97d_level1_col3" class="col_heading level1 col3" >-1.000000</th>
#       <th id="T_5b97d_level1_col4" class="col_heading level1 col4" >-1.000000</th>
#       <th id="T_5b97d_level1_col5" class="col_heading level1 col5" >0.280000</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b97d_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_5b97d_row0_col0" class="data row0 col0" >S01</td>
#       <td id="T_5b97d_row0_col1" class="data row0 col1" >0.032</td>
#       <td id="T_5b97d_row0_col2" class="data row0 col2" >0.023</td>
#       <td id="T_5b97d_row0_col3" class="data row0 col3" >0.029</td>
#       <td id="T_5b97d_row0_col4" class="data row0 col4" >0.019</td>
#       <td id="T_5b97d_row0_col5" class="data row0 col5" >0.038</td>
#     </tr>
#     <tr>
#       <th id="T_5b97d_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_5b97d_row1_col0" class="data row1 col0" >S02</td>
#       <td id="T_5b97d_row1_col1" class="data row1 col1" >0.076</td>
#       <td id="T_5b97d_row1_col2" class="data row1 col2" >0.064</td>
#       <td id="T_5b97d_row1_col3" class="data row1 col3" >0.089</td>
#       <td id="T_5b97d_row1_col4" class="data row1 col4" >0.080</td>
#       <td id="T_5b97d_row1_col5" class="data row1 col5" >0.082</td>
#     </tr>
#     <tr>
#       <th id="T_5b97d_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_5b97d_row2_col0" class="data row2 col0" >S03</td>
#       <td id="T_5b97d_row2_col1" class="data row2 col1" >0.051</td>
#       <td id="T_5b97d_row2_col2" class="data row2 col2" >0.070</td>
#       <td id="T_5b97d_row2_col3" class="data row2 col3" >0.102</td>
#       <td id="T_5b97d_row2_col4" class="data row2 col4" >0.092</td>
#       <td id="T_5b97d_row2_col5" class="data row2 col5" >0.109</td>
#     </tr>
#     <tr>
#       <th id="T_5b97d_level0_row3" class="row_heading level0 row3" >14</th>
#       <td id="T_5b97d_row3_col0" class="data row3 col0" >S04</td>
#       <td id="T_5b97d_row3_col1" class="data row3 col1" >0.016</td>
#       <td id="T_5b97d_row3_col2" class="data row3 col2" >0.010</td>
#       <td id="T_5b97d_row3_col3" class="data row3 col3" >0.033</td>
#       <td id="T_5b97d_row3_col4" class="data row3 col4" >0.023</td>
#       <td id="T_5b97d_row3_col5" class="data row3 col5" >0.037</td>
#     </tr>
#     <tr>
#       <th id="T_5b97d_level0_row4" class="row_heading level0 row4" >18</th>
#       <td id="T_5b97d_row4_col0" class="data row4 col0" >S05</td>
#       <td id="T_5b97d_row4_col1" class="data row4 col1" >0.009</td>
#       <td id="T_5b97d_row4_col2" class="data row4 col2" >0.012</td>
#       <td id="T_5b97d_row4_col3" class="data row4 col3" >0.000</td>
#       <td id="T_5b97d_row4_col4" class="data row4 col4" >0.011</td>
#       <td id="T_5b97d_row4_col5" class="data row4 col5" >0.030</td>
#     </tr>
#     <tr>
#       <th id="T_5b97d_level0_row5" class="row_heading level0 row5" >22</th>
#       <td id="T_5b97d_row5_col0" class="data row5 col0" >S06</td>
#       <td id="T_5b97d_row5_col1" class="data row5 col1" >0.025</td>
#       <td id="T_5b97d_row5_col2" class="data row5 col2" >0.017</td>
#       <td id="T_5b97d_row5_col3" class="data row5 col3" >0.035</td>
#       <td id="T_5b97d_row5_col4" class="data row5 col4" >0.036</td>
#       <td id="T_5b97d_row5_col5" class="data row5 col5" >0.034</td>
#     </tr>
#     <tr>
#       <th id="T_5b97d_level0_row6" class="row_heading level0 row6" >26</th>
#       <td id="T_5b97d_row6_col0" class="data row6 col0" >S07</td>
#       <td id="T_5b97d_row6_col1" class="data row6 col1" >0.023</td>
#       <td id="T_5b97d_row6_col2" class="data row6 col2" >0.017</td>
#       <td id="T_5b97d_row6_col3" class="data row6 col3" >0.020</td>
#       <td id="T_5b97d_row6_col4" class="data row6 col4" >0.026</td>
#       <td id="T_5b97d_row6_col5" class="data row6 col5" >0.028</td>
#     </tr>
#     <tr>
#       <th id="T_5b97d_level0_row7" class="row_heading level0 row7" >30</th>
#       <td id="T_5b97d_row7_col0" class="data row7 col0" >S08</td>
#       <td id="T_5b97d_row7_col1" class="data row7 col1" >0.009</td>
#       <td id="T_5b97d_row7_col2" class="data row7 col2" >0.006</td>
#       <td id="T_5b97d_row7_col3" class="data row7 col3" >0.007</td>
#       <td id="T_5b97d_row7_col4" class="data row7 col4" >0.010</td>
#       <td id="T_5b97d_row7_col5" class="data row7 col5" >0.014</td>
#     </tr>
#   </tbody>
# </table>
# num_stories = 100
# /tmp/ipykernel_2201942/1032307835.py:7: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   display(dn.drop(columns=['num_stories']).style.background_gradient(
# <style type="text/css">
# #T_4a354_row0_col1 {
#   background-color: #fde7a9;
#   color: #000000;
# }
# #T_4a354_row0_col2 {
#   background-color: #491078;
#   color: #f1f1f1;
# }
# #T_4a354_row0_col3, #T_4a354_row1_col2, #T_4a354_row2_col2, #T_4a354_row3_col1, #T_4a354_row4_col3, #T_4a354_row5_col2, #T_4a354_row6_col2, #T_4a354_row7_col3 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_4a354_row0_col4, #T_4a354_row1_col4, #T_4a354_row2_col3, #T_4a354_row3_col5, #T_4a354_row4_col5, #T_4a354_row5_col3, #T_4a354_row6_col5, #T_4a354_row7_col2 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_4a354_row0_col5 {
#   background-color: #fcf6b8;
#   color: #000000;
# }
# #T_4a354_row1_col1 {
#   background-color: #e75263;
#   color: #f1f1f1;
# }
# #T_4a354_row1_col3, #T_4a354_row4_col2 {
#   background-color: #8b2981;
#   color: #f1f1f1;
# }
# #T_4a354_row1_col5 {
#   background-color: #d5446d;
#   color: #f1f1f1;
# }
# #T_4a354_row2_col1 {
#   background-color: #f7725c;
#   color: #f1f1f1;
# }
# #T_4a354_row2_col4 {
#   background-color: #f56b5c;
#   color: #f1f1f1;
# }
# #T_4a354_row2_col5 {
#   background-color: #a8327d;
#   color: #f1f1f1;
# }
# #T_4a354_row3_col2 {
#   background-color: #fec88c;
#   color: #000000;
# }
# #T_4a354_row3_col3 {
#   background-color: #db476a;
#   color: #f1f1f1;
# }
# #T_4a354_row3_col4 {
#   background-color: #f4695c;
#   color: #f1f1f1;
# }
# #T_4a354_row4_col1 {
#   background-color: #20114b;
#   color: #f1f1f1;
# }
# #T_4a354_row4_col4 {
#   background-color: #892881;
#   color: #f1f1f1;
# }
# #T_4a354_row5_col1 {
#   background-color: #fc8c63;
#   color: #f1f1f1;
# }
# #T_4a354_row5_col4 {
#   background-color: #fdebac;
#   color: #000000;
# }
# #T_4a354_row5_col5 {
#   background-color: #fc8e64;
#   color: #000000;
# }
# #T_4a354_row6_col1 {
#   background-color: #451077;
#   color: #f1f1f1;
# }
# #T_4a354_row6_col3 {
#   background-color: #a02f7f;
#   color: #f1f1f1;
# }
# #T_4a354_row6_col4 {
#   background-color: #fe9d6c;
#   color: #000000;
# }
# #T_4a354_row7_col1 {
#   background-color: #29115a;
#   color: #f1f1f1;
# }
# #T_4a354_row7_col4 {
#   background-color: #ad347c;
#   color: #f1f1f1;
# }
# #T_4a354_row7_col5 {
#   background-color: #fddc9e;
#   color: #000000;
# }
# </style>
# <table id="T_4a354">
#   <thead>
#     <tr>
#       <th class="index_name level0" >feature_space_simplified</th>
#       <th id="T_4a354_level0_col0" class="col_heading level0 col0" >subject</th>
#       <th id="T_4a354_level0_col1" class="col_heading level0 col1" >bert-base-uncased</th>
#       <th id="T_4a354_level0_col2" class="col_heading level0 col2" >eng1000</th>
#       <th id="T_4a354_level0_col3" class="col_heading level0 col3" >llama</th>
#       <th id="T_4a354_level0_col4" class="col_heading level0 col4" colspan="2">qa_embedder</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >feature_selection_alpha</th>
#       <th id="T_4a354_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_4a354_level1_col1" class="col_heading level1 col1" >-1.000000</th>
#       <th id="T_4a354_level1_col2" class="col_heading level1 col2" >-1.000000</th>
#       <th id="T_4a354_level1_col3" class="col_heading level1 col3" >-1.000000</th>
#       <th id="T_4a354_level1_col4" class="col_heading level1 col4" >-1.000000</th>
#       <th id="T_4a354_level1_col5" class="col_heading level1 col5" >0.280000</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a354_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_4a354_row0_col0" class="data row0 col0" >S01</td>
#       <td id="T_4a354_row0_col1" class="data row0 col1" >0.056</td>
#       <td id="T_4a354_row0_col2" class="data row0 col2" >0.049</td>
#       <td id="T_4a354_row0_col3" class="data row0 col3" >0.047</td>
#       <td id="T_4a354_row0_col4" class="data row0 col4" >0.057</td>
#       <td id="T_4a354_row0_col5" class="data row0 col5" >0.057</td>
#     </tr>
#     <tr>
#       <th id="T_4a354_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_4a354_row1_col0" class="data row1 col0" >S02</td>
#       <td id="T_4a354_row1_col1" class="data row1 col1" >0.112</td>
#       <td id="T_4a354_row1_col2" class="data row1 col2" >0.095</td>
#       <td id="T_4a354_row1_col3" class="data row1 col3" >0.106</td>
#       <td id="T_4a354_row1_col4" class="data row1 col4" >0.123</td>
#       <td id="T_4a354_row1_col5" class="data row1 col5" >0.111</td>
#     </tr>
#     <tr>
#       <th id="T_4a354_level0_row2" class="row_heading level0 row2" >11</th>
#       <td id="T_4a354_row2_col0" class="data row2 col0" >S03</td>
#       <td id="T_4a354_row2_col1" class="data row2 col1" >0.133</td>
#       <td id="T_4a354_row2_col2" class="data row2 col2" >0.107</td>
#       <td id="T_4a354_row2_col3" class="data row2 col3" >0.145</td>
#       <td id="T_4a354_row2_col4" class="data row2 col4" >0.133</td>
#       <td id="T_4a354_row2_col5" class="data row2 col5" >0.124</td>
#     </tr>
#     <tr>
#       <th id="T_4a354_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_4a354_row3_col0" class="data row3 col0" >S04</td>
#       <td id="T_4a354_row3_col1" class="data row3 col1" >0.001</td>
#       <td id="T_4a354_row3_col2" class="data row3 col2" >0.038</td>
#       <td id="T_4a354_row3_col3" class="data row3 col3" >0.026</td>
#       <td id="T_4a354_row3_col4" class="data row3 col4" >0.030</td>
#       <td id="T_4a354_row3_col5" class="data row3 col5" >0.043</td>
#     </tr>
#     <tr>
#       <th id="T_4a354_level0_row4" class="row_heading level0 row4" >19</th>
#       <td id="T_4a354_row4_col0" class="data row4 col0" >S05</td>
#       <td id="T_4a354_row4_col1" class="data row4 col1" >0.010</td>
#       <td id="T_4a354_row4_col2" class="data row4 col2" >0.017</td>
#       <td id="T_4a354_row4_col3" class="data row4 col3" >0.007</td>
#       <td id="T_4a354_row4_col4" class="data row4 col4" >0.017</td>
#       <td id="T_4a354_row4_col5" class="data row4 col5" >0.032</td>
#     </tr>
#     <tr>
#       <th id="T_4a354_level0_row5" class="row_heading level0 row5" >23</th>
#       <td id="T_4a354_row5_col0" class="data row5 col0" >S06</td>
#       <td id="T_4a354_row5_col1" class="data row5 col1" >0.035</td>
#       <td id="T_4a354_row5_col2" class="data row5 col2" >0.019</td>
#       <td id="T_4a354_row5_col3" class="data row5 col3" >0.041</td>
#       <td id="T_4a354_row5_col4" class="data row5 col4" >0.040</td>
#       <td id="T_4a354_row5_col5" class="data row5 col5" >0.036</td>
#     </tr>
#     <tr>
#       <th id="T_4a354_level0_row6" class="row_heading level0 row6" >27</th>
#       <td id="T_4a354_row6_col0" class="data row6 col0" >S07</td>
#       <td id="T_4a354_row6_col1" class="data row6 col1" >0.022</td>
#       <td id="T_4a354_row6_col2" class="data row6 col2" >0.019</td>
#       <td id="T_4a354_row6_col3" class="data row6 col3" >0.025</td>
#       <td id="T_4a354_row6_col4" class="data row6 col4" >0.029</td>
#       <td id="T_4a354_row6_col5" class="data row6 col5" >0.032</td>
#     </tr>
#     <tr>
#       <th id="T_4a354_level0_row7" class="row_heading level0 row7" >31</th>
#       <td id="T_4a354_row7_col0" class="data row7 col0" >S08</td>
#       <td id="T_4a354_row7_col1" class="data row7 col1" >0.008</td>
#       <td id="T_4a354_row7_col2" class="data row7 col2" >0.016</td>
#       <td id="T_4a354_row7_col3" class="data row7 col3" >0.007</td>
#       <td id="T_4a354_row7_col4" class="data row7 col4" >0.011</td>
#       <td id="T_4a354_row7_col5" class="data row7 col5" >0.015</td>
#     </tr>
#   </tbody>
# </table>
